# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key from a file that is ignored by Git (.gitignore file) so the key isn't exposed to the public

from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)

output_data_file = "/output_data/cities.csv"

# %%
# Identify range of latitudes/longitudes

lat_range = (-90, 90)
lng_range = (-180, 180)

# Create List for holding lat_lngs and Cities

lat_lngs = []
cities = []
countries = []

# Create sets of random latitude/longitude combinations -- Zip into list of Tuples

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify closest City for each latitude/longitude combination using Citypy -- Return unique Cities and Country codes

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If City is unique, add to Cities List
    
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Merge the two lists into one List of Tuples using Zip

city_country = zip(cities,countries)

# Print City Count -- Confirm value is greater than 500
print(len(cities))
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Config information

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Lists to hold reponse information

city_id = []
city_name = []
country = []
latitude = []
longitude = []
weather_date = []
temp = []
humidity = []
cloudiness = []
wind_speed = []

# Open file to write results of API calls - success or not into a txt file, as well as all data pulled into a csv

myprintlog = open('weatherAPI_printlog.txt', 'w')
myAPIdata = open('weatherAPI_data.csv', 'w')

# Write header line for csv file
myAPIdata.write("city_id,city_name,country,latitude,longitude,weather_date,temp,humidity,cloudiness,wind_speed\n")

# Loop through the list of tuples of cities,country codes and perform a request for data on each
for city,country_code in city_country:
    query_url = f"{url}appid={weather_api_key}&q={city},{country_code}&units={units}"
    response = requests.get(query_url).json()

    # Try to grab the temp,humidity,cloudiness and wind speed if they are available in the Weather API
    # if the city is not found on the WeatherAPI site then the "except" will catch the error and the loop will
    # continue to go through the rest of the city,country_codes in the city_country list
    try:
        # Create variables for each response item and format to desired datatype
        cityID = int(response['id'])
        cityName = response['name']
        countryCode = response['sys']['country']
        lat_val = response['coord']['lat']
        lon_val = response['coord']['lon']
        weatherDate = (datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y')
        temperature = response['main']['temp']
        humidity_val = response['main']['humidity']
        cloudiness_val = response['clouds']['all']
        windSpeed = response['wind']['speed']
        
        # Append retreived values to lists above using the variables created above
        city_id.append(cityID)
        city_name.append(cityName)
        country.append(countryCode)
        latitude.append(lat_val)
        longitude.append(lon_val)
        weather_date.append(weatherDate)
        temp.append(temperature)
        humidity.append(humidity_val)
        cloudiness.append(cloudiness_val)
        wind_speed.append(windSpeed)
        
        # Output line to terminal to mark progress and store it to a print log text file
        
        print(f"{cityName} with city ID:{cityID} was found in the Weathermap API\n")
        myprintlog.write(f"{cityName} with city ID:{cityID} was found in the Weathermap API\n")
        
        # Output Retreived values to CSV file
        
        myAPIdata.write(f"{cityID},{cityName},{countryCode},{lat_val},{lon_val},{weatherDate},\
            {temperature},{humidity_val},{cloudiness_val},{windSpeed}\n")
        
        # Create Handler for exceptions when Cities are not available in Weather API
        
    except:
        
        print(f"{city},{country_code} was not found in the Weathermap API\n")
        myprintlog.write(f"{city},{country_code} was not found in the Weathermap API\n")
        
        # Append Null Values so lists are same lengths
        
        city_id.append(None)
        city_name.append(None)
        country.append(None)
        latitude.append(None)
        longitude.append(None)
        weather_date.append(None)
        temp.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind_speed.append(None)
        pass
    
# Close file handle after loop completes

myprintlog.close()
myAPIdata.close()
# Out:
# Necochea with city ID:3430443 was found in the Weathermap API
#
# Albany with city ID:2077963 was found in the Weathermap API
#
# Safi with city ID:2537881 was found in the Weathermap API
#
# São Félix do Xingu with city ID:3388847 was found in the Weathermap API
#
# barentsburg,sj was not found in the Weathermap API
#
# Torbay with city ID:6167817 was found in the Weathermap API
#
# San Policarpo with city ID:1688696 was found in the Weathermap API
#
# Georgetown with city ID:2411397 was found in the Weathermap API
#
# Khandyga with city ID:2022773 was found in the Weathermap API
#
# Bluff with city ID:2206939 was found in the Weathermap API
#
# Yellowknife with city ID:6185377 was found in the Weathermap API
#
# Severo-Kuril'sk with city ID:2121385 was found in the Weathermap API
#
# Rikitea with city ID:4030556 was found in the Weathermap API
#
# Avarua with city ID:4035715 was found in the Weathermap API
#
# Rocha with city ID:3440777 was found in the Weathermap API
#
# Birao with city ID:240210 was found in the Weathermap API
#
# Puerto Madero with city ID:3520989 was found in the Weathermap API
#
# Ushuaia with city ID:3833367 was found in the Weathermap API
#
# Ribeira Grande with city ID:3372707 was found in the Weathermap API
#
# Strezhevoy with city ID:1490796 was found in the Weathermap API
#
# Coyhaique with city ID:3894426 was found in the Weathermap API
#
# Eureka with city ID:5563397 was found in the Weathermap API
#
# São Filipe with city ID:3374210 was found in the Weathermap API
#
# Coquimbo with city ID:3893629 was found in the Weathermap API
#
# illoqqortoormiut,gl was not found in the Weathermap API
#
# Puerto Ayora with city ID:3652764 was found in the Weathermap API
#
# Hilo with city ID:5855927 was found in the Weathermap API
#
# Dikson with city ID:1507390 was found in the Weathermap API
#
# Busselton with city ID:2075265 was found in the Weathermap API
#
# Atuona with city ID:4020109 was found in the Weathermap API
#
# Saint-Philippe with city ID:935215 was found in the Weathermap API
#
# Laguna with city ID:3459094 was found in the Weathermap API
#
# Kapaa with city ID:5848280 was found in the Weathermap API
#
# Babu with city ID:1817858 was found in the Weathermap API
#
# Port Elizabeth with city ID:964420 was found in the Weathermap API
#
# Cape Town with city ID:3369157 was found in the Weathermap API
#
# Bredasdorp with city ID:1015776 was found in the Weathermap API
#
# Esim with city ID:2303611 was found in the Weathermap API
#
# Hermanus with city ID:3366880 was found in the Weathermap API
#
# Kadaya with city ID:2023324 was found in the Weathermap API
#
# Filingué with city ID:2444995 was found in the Weathermap API
#
# Nyimba with city ID:900056 was found in the Weathermap API
#
# Nikolskoye with city ID:546105 was found in the Weathermap API
#
# Maniitsoq with city ID:3421982 was found in the Weathermap API
#
# goderich,sl was not found in the Weathermap API
#
# Pozo Colorado with city ID:3437443 was found in the Weathermap API
#
# Esperance with city ID:2071860 was found in the Weathermap API
#
# Kysyl-Syr with city ID:2021017 was found in the Weathermap API
#
# Jamestown with city ID:3370903 was found in the Weathermap API
#
# tawkar,sd was not found in the Weathermap API
#
# Umm Kaddadah with city ID:364933 was found in the Weathermap API
#
# Churapcha with city ID:2025241 was found in the Weathermap API
#
# Qasigiannguit with city ID:3420768 was found in the Weathermap API
#
# Nome with city ID:5870133 was found in the Weathermap API
#
# Verāval with city ID:1253237 was found in the Weathermap API
#
# veraval,in was not found in the Weathermap API
#
# saint anthony,ca was not found in the Weathermap API
#
# Terrace with city ID:6162949 was found in the Weathermap API
#
# Reconquista with city ID:3429594 was found in the Weathermap API
#
# Butaritari with city ID:2110227 was found in the Weathermap API
#
# Ponta do Sol with city ID:3374346 was found in the Weathermap API
#
# Vostok with city ID:2013279 was found in the Weathermap API
#
# Araceli with city ID:1730272 was found in the Weathermap API
#
# Sitka with city ID:5557293 was found in the Weathermap API
#
# Juegang with city ID:1804979 was found in the Weathermap API
#
# Te Anau with city ID:2181625 was found in the Weathermap API
#
# belushya guba,ru was not found in the Weathermap API
#
# Martvili with city ID:613065 was found in the Weathermap API
#
# Kavieng with city ID:2094342 was found in the Weathermap API
#
# East London with city ID:1006984 was found in the Weathermap API
#
# Saskylakh with city ID:2017155 was found in the Weathermap API
#
# Statesville with city ID:4493316 was found in the Weathermap API
#
# La Ronge with city ID:6050066 was found in the Weathermap API
#
# Fortuna with city ID:5563839 was found in the Weathermap API
#
# Tuktoyaktuk with city ID:6170031 was found in the Weathermap API
#
# Hobart with city ID:2163355 was found in the Weathermap API
#
# Mar del Plata with city ID:3430863 was found in the Weathermap API
#
# Tazovsky with city ID:1489853 was found in the Weathermap API
#
# lasa,cn was not found in the Weathermap API
#
# Khatanga with city ID:2022572 was found in the Weathermap API
#
# palabuhanratu,id was not found in the Weathermap API
#
# Biak with city ID:1637001 was found in the Weathermap API
#
# Castro with city ID:3896218 was found in the Weathermap API
#
# Cherskiy with city ID:2126199 was found in the Weathermap API
#
# alekseyevka,kz was not found in the Weathermap API
#
# Vaini with city ID:4032243 was found in the Weathermap API
#
# Killybegs with city ID:2963295 was found in the Weathermap API
#
# Promyshlennaya with city ID:1494091 was found in the Weathermap API
#
# Vila Velha with city ID:3445026 was found in the Weathermap API
#
# Margate with city ID:978895 was found in the Weathermap API
#
# North Bend with city ID:5742974 was found in the Weathermap API
#
# Dingle with city ID:2964782 was found in the Weathermap API
#
# Alofi with city ID:4036284 was found in the Weathermap API
#
# Lüderitz with city ID:3355672 was found in the Weathermap API
#
# Punta Arenas with city ID:3874787 was found in the Weathermap API
#
# Springdale with city ID:4132093 was found in the Weathermap API
#
# Isangel with city ID:2136825 was found in the Weathermap API
#
# Biu with city ID:2346995 was found in the Weathermap API
#
# Port Lincoln with city ID:2063036 was found in the Weathermap API
#
# Ambilobe with city ID:1082243 was found in the Weathermap API
#
# Faanui with city ID:4034551 was found in the Weathermap API
#
# Lompoc with city ID:5367788 was found in the Weathermap API
#
# Baykit with city ID:1510689 was found in the Weathermap API
#
# Chumikan with city ID:2025256 was found in the Weathermap API
#
# Norman Wells with city ID:6089245 was found in the Weathermap API
#
# Carnarvon with city ID:2074865 was found in the Weathermap API
#
# Lang Suan with city ID:1152432 was found in the Weathermap API
#
# sataua,ws was not found in the Weathermap API
#
# Nanortalik with city ID:3421765 was found in the Weathermap API
#
# Darya Khan with city ID:1180454 was found in the Weathermap API
#
# Vuktyl with city ID:470905 was found in the Weathermap API
#
# Nemuro with city ID:2128975 was found in the Weathermap API
#
# Berdigestyakh with city ID:2026861 was found in the Weathermap API
#
# Arraial do Cabo with city ID:3471451 was found in the Weathermap API
#
# Quatre Cocos with city ID:1106643 was found in the Weathermap API
#
# Shestakovo with city ID:2016733 was found in the Weathermap API
#
# Prieska with city ID:964090 was found in the Weathermap API
#
# Broome with city ID:2075720 was found in the Weathermap API
#
# Panabá with city ID:3521972 was found in the Weathermap API
#
# Harar with city ID:335035 was found in the Weathermap API
#
# Edéa with city ID:2232239 was found in the Weathermap API
#
# Kenai with city ID:5866063 was found in the Weathermap API
#
# Bandarbeyla with city ID:64814 was found in the Weathermap API
#
# burica,pa was not found in the Weathermap API
#
# Lorengau with city ID:2092164 was found in the Weathermap API
#
# Sobolevo with city ID:525426 was found in the Weathermap API
#
# Umluj with city ID:100926 was found in the Weathermap API
#
# Riosucio with city ID:3670719 was found in the Weathermap API
#
# Kolokani with city ID:2454955 was found in the Weathermap API
#
# Pīpār with city ID:1259608 was found in the Weathermap API
#
# pipar,in was not found in the Weathermap API
#
# Ubari with city ID:2219235 was found in the Weathermap API
#
# Iquique with city ID:3887127 was found in the Weathermap API
#
# Vadlapūdi with city ID:1253578 was found in the Weathermap API
#
# vadlapudi,in was not found in the Weathermap API
# Rehoboth with city ID:3353540 was found in the Weathermap API
#
# Avigliana with city ID:3182634 was found in the Weathermap API
#
# Yangjiang with city ID:1806408 was found in the Weathermap API
#
# Thompson with city ID:6165406 was found in the Weathermap API
#
# Aitape with city ID:2101169 was found in the Weathermap API
#
# Maragogi with city ID:3395458 was found in the Weathermap API
#
# Barrow with city ID:5880054 was found in the Weathermap API
#
# Mahébourg with city ID:934322 was found in the Weathermap API
#
# Cidreira with city ID:3466165 was found in the Weathermap API
#
# Batatais with city ID:3470324 was found in the Weathermap API
#
# Porto Novo with city ID:3374336 was found in the Weathermap API
#
# Erzin with city ID:1506938 was found in the Weathermap API
#
# Roald with city ID:3141667 was found in the Weathermap API
#
# Port Alfred with city ID:964432 was found in the Weathermap API
#
# Acapulco de Juárez with city ID:3533462 was found in the Weathermap API
#
# Dickinson with city ID:4686163 was found in the Weathermap API
#
# Miyako with city ID:2111884 was found in the Weathermap API
#
# Yulara with city ID:6355222 was found in the Weathermap API
#
# Saint George with city ID:3573061 was found in the Weathermap API
#
# Berezniki with city ID:577206 was found in the Weathermap API
#
# mataura,pf was not found in the Weathermap API
#
# Touros with city ID:3386213 was found in the Weathermap API
#
# sentyabrskiy,ru was not found in the Weathermap API
#
# Vilhena with city ID:3924679 was found in the Weathermap API
#
# Clyde River with city ID:5924351 was found in the Weathermap API
#
# Kumul with city ID:1529484 was found in the Weathermap API
#
# Rudnyy with city ID:2017377 was found in the Weathermap API
#
# Polunochnoye with city ID:1494482 was found in the Weathermap API
#
# Caluquembe with city ID:3351024 was found in the Weathermap API
#
# taolanaro,mg was not found in the Weathermap API
#
# Mundo Nuevo (Ojo de Agua) with city ID:3522880 was found in the Weathermap API
#
# Takanosu with city ID:2127910 was found in the Weathermap API
#
# Namatanai with city ID:2090021 was found in the Weathermap API
#
# Kozan with city ID:306112 was found in the Weathermap API
#
# Emerald with city ID:2167426 was found in the Weathermap API
#
# Bemidji with city ID:5017822 was found in the Weathermap API
#
# Berbera with city ID:64435 was found in the Weathermap API
#
# Ürümqi with city ID:1529102 was found in the Weathermap API
#
# Colares with city ID:2269142 was found in the Weathermap API
#
# Kiama with city ID:2161515 was found in the Weathermap API
#
# Conde with city ID:3385077 was found in the Weathermap API
#
# Yantal' with city ID:2055868 was found in the Weathermap API
#
# temaraia,ki was not found in the Weathermap API
#
# Zharkent with city ID:1520253 was found in the Weathermap API
#
# Praia with city ID:3374333 was found in the Weathermap API
#
# Seryshevo with city ID:2016942 was found in the Weathermap API
#
# Taltal with city ID:3870243 was found in the Weathermap API
#
# Sola with city ID:2134814 was found in the Weathermap API
#
# nizhneyansk,ru was not found in the Weathermap API
#
# Hasaki with city ID:2112802 was found in the Weathermap API
#
# faya,td was not found in the Weathermap API
#
# Ilulissat with city ID:3423146 was found in the Weathermap API
#
# Raudeberg with city ID:3146487 was found in the Weathermap API
#
# marcona,pe was not found in the Weathermap API
#
# Port Shepstone with city ID:964406 was found in the Weathermap API
#
# Hithadhoo with city ID:1282256 was found in the Weathermap API
#
# New Norfolk with city ID:2155415 was found in the Weathermap API
#
# Lapi with city ID:1707316 was found in the Weathermap API
#
# Pontianak with city ID:1630789 was found in the Weathermap API
#
# grand river south east,mu was not found in the Weathermap API
#
# Oruro with city ID:3909234 was found in the Weathermap API
#
# Arlit with city ID:2447513 was found in the Weathermap API
#
# Tarko-Sale with city ID:1490085 was found in the Weathermap API
#
# Oussouye with city ID:2246901 was found in the Weathermap API
#
# Flinders with city ID:6255012 was found in the Weathermap API
#
# Hofn with city ID:2630299 was found in the Weathermap API
#
# Shediac with city ID:6145668 was found in the Weathermap API
#
# Makakilo City with city ID:5850554 was found in the Weathermap API
#
# Victoria with city ID:241131 was found in the Weathermap API
#
# Petropavlovsk-Kamchatskiy with city ID:2122104 was found in the Weathermap API
#
# Beidao with city ID:1816751 was found in the Weathermap API
#
# saleaula,ws was not found in the Weathermap API
#
# Hualmay with city ID:3939761 was found in the Weathermap API
#
# Skellefteå with city ID:602913 was found in the Weathermap API
#
# Madang with city ID:2091996 was found in the Weathermap API
#
# Dunedin with city ID:2191562 was found in the Weathermap API
#
# Yamada with city ID:2110560 was found in the Weathermap API
#
# Bathsheba with city ID:3374083 was found in the Weathermap API
#
# Lázaro Cárdenas with city ID:4026082 was found in the Weathermap API
#
# Kruisfontein with city ID:986717 was found in the Weathermap API
#
# Republic with city ID:4405434 was found in the Weathermap API
#
# Tasiilaq with city ID:3424607 was found in the Weathermap API
#
# Gouyave with city ID:3580279 was found in the Weathermap API
#
# Sampit with city ID:1628884 was found in the Weathermap API
#
# Egvekinot with city ID:4031742 was found in the Weathermap API
#
# Karratha with city ID:6620339 was found in the Weathermap API
#
# Bambous Virieux with city ID:1106677 was found in the Weathermap API
#
# Tempio Pausania with city ID:3165828 was found in the Weathermap API
#
# Kirakira with city ID:2178753 was found in the Weathermap API
#
# Anloga with city ID:2304548 was found in the Weathermap API
#
# San Patricio with city ID:3985168 was found in the Weathermap API
#
# Komsomol'skiy with city ID:545728 was found in the Weathermap API
#
# bur gabo,so was not found in the Weathermap API
#
# Banda Aceh with city ID:1215502 was found in the Weathermap API
#
# Boa Vista with city ID:3664980 was found in the Weathermap API
#
# Bethel with city ID:5282297 was found in the Weathermap API
#
# Rairangpur with city ID:1265830 was found in the Weathermap API
#
# Tiksi with city ID:2015306 was found in the Weathermap API
#
# Manjeshwar with city ID:1263780 was found in the Weathermap API
#
# Zyryanka with city ID:2119283 was found in the Weathermap API
#
# Pincher Creek with city ID:6104841 was found in the Weathermap API
#
# Svetlaya with city ID:2015852 was found in the Weathermap API
#
# Riohacha with city ID:3670745 was found in the Weathermap API
#
# Jacareacanga with city ID:3397763 was found in the Weathermap API
#
# Barsovo with city ID:1510842 was found in the Weathermap API
#
# College with city ID:5859699 was found in the Weathermap API
#
# Kommunarka with city ID:545782 was found in the Weathermap API
#
# Provideniya with city ID:4031574 was found in the Weathermap API
#
# Khāsh with city ID:1160571 was found in the Weathermap API
#
# khash,ir was not found in the Weathermap API
#
# Srednekolymsk with city ID:2121025 was found in the Weathermap API
#
# Nouakchott with city ID:2377450 was found in the Weathermap API
#
# Kahului with city ID:5847411 was found in the Weathermap API
#
# Malim with city ID:1958659 was found in the Weathermap API
#
# Nishihara with city ID:1855342 was found in the Weathermap API
#
# Bilma with city ID:2446796 was found in the Weathermap API
#
# Qaanaaq with city ID:3831208 was found in the Weathermap API
#
# Port Blair with city ID:1259385 was found in the Weathermap API
#
# Portland with city ID:2152667 was found in the Weathermap API
#
# Grindavik with city ID:3416888 was found in the Weathermap API
#
# amderma,ru was not found in the Weathermap API
#
# Kupang with city ID:2057087 was found in the Weathermap API
#
# samalaeulu,ws was not found in the Weathermap API
#
# Caucayá with city ID:3671437 was found in the Weathermap API
#
# Joshīmath with city ID:1268814 was found in the Weathermap API
#
# joshimath,in was not found in the Weathermap API
#
# attawapiskat,ca was not found in the Weathermap API
#
# Yar-Sale with city ID:1486321 was found in the Weathermap API
#
# Linhares with city ID:3458498 was found in the Weathermap API
#
# Talcahuano with city ID:3870282 was found in the Weathermap API
#
# requena,pe was not found in the Weathermap API
#
# Nara with city ID:6779095 was found in the Weathermap API
#
# Smidovich with city ID:2016412 was found in the Weathermap API
#
# Pevek with city ID:2122090 was found in the Weathermap API
# Kaitangata with city ID:2208248 was found in the Weathermap API
#
# Tokur with city ID:2015217 was found in the Weathermap API
#
# Aktobe with city ID:610611 was found in the Weathermap API
#
# Buraidah with city ID:107304 was found in the Weathermap API
#
# umzimvubu,za was not found in the Weathermap API
#
# saint paul,ca was not found in the Weathermap API
#
# Błonie with city ID:775820 was found in the Weathermap API
#
# blonie,pl was not found in the Weathermap API
#
# Lebu with city ID:3883457 was found in the Weathermap API
#
# Mossamedes with city ID:3347019 was found in the Weathermap API
#
# Gigmoto with city ID:1712961 was found in the Weathermap API
#
# Viedma with city ID:3832899 was found in the Weathermap API
#
# palaiokhora,gr was not found in the Weathermap API
#
# podujevo,rs was not found in the Weathermap API
#
# Cayenne with city ID:3382160 was found in the Weathermap API
#
# Constitucion with city ID:4011743 was found in the Weathermap API
#
# Jurm with city ID:1139085 was found in the Weathermap API
#
# Bermeo with city ID:3128174 was found in the Weathermap API
#
# Kalmunai with city ID:1242110 was found in the Weathermap API
#
# Paamiut with city ID:3421193 was found in the Weathermap API
#
# mys shmidta,ru was not found in the Weathermap API
#
# Challapata with city ID:3921355 was found in the Weathermap API
#
# Rio Grande with city ID:3451138 was found in the Weathermap API
#
# grande-riviere,ca was not found in the Weathermap API
#
# Pandan with city ID:1695546 was found in the Weathermap API
#
# Rāpar with city ID:1258406 was found in the Weathermap API
#
# rapar,in was not found in the Weathermap API
#
# Kyren with city ID:2021031 was found in the Weathermap API
#
# taga,ws was not found in the Weathermap API
#
# Camopi with city ID:3382226 was found in the Weathermap API
#
# Saint-Lô with city ID:2978758 was found in the Weathermap API
#
# El Centro with city ID:5345609 was found in the Weathermap API
#
# Kristinestad with city ID:650769 was found in the Weathermap API
#
# Cabo San Lucas with city ID:3985710 was found in the Weathermap API
#
# Nuquí with city ID:3673690 was found in the Weathermap API
#
# mrirt,ma was not found in the Weathermap API
#
# Kisangani with city ID:212730 was found in the Weathermap API
#
# Praia da Vitória with city ID:3372760 was found in the Weathermap API
#
# ginda,er was not found in the Weathermap API
#
# Liseleje with city ID:2617538 was found in the Weathermap API
#
# Honningsvåg with city ID:779554 was found in the Weathermap API
#
# San Quintín with city ID:3984997 was found in the Weathermap API
#
# Salalah with city ID:286621 was found in the Weathermap API
#
# Chokurdakh with city ID:2126123 was found in the Weathermap API
#
# Ben Gardane with city ID:2472431 was found in the Weathermap API
#
# Vardø with city ID:777019 was found in the Weathermap API
#
# codrington,ag was not found in the Weathermap API
#
# Inhambane with city ID:1045114 was found in the Weathermap API
#
# Lyuban' with city ID:625721 was found in the Weathermap API
#
# Brae with city ID:2654970 was found in the Weathermap API
#
# Minas with city ID:3441665 was found in the Weathermap API
#
# Upernavik with city ID:3418910 was found in the Weathermap API
#
# Jiwani with city ID:1175712 was found in the Weathermap API
#
# Grand Gaube with city ID:934479 was found in the Weathermap API
#
# Sept-Îles with city ID:6144312 was found in the Weathermap API
#
# Auki with city ID:2109701 was found in the Weathermap API
#
# Haines Junction with city ID:5969025 was found in the Weathermap API
#
# Rawson with city ID:3839307 was found in the Weathermap API
#
# Pringsewu with city ID:1630639 was found in the Weathermap API
#
# Villarrica with city ID:3868158 was found in the Weathermap API
#
# Kalawit with city ID:1709653 was found in the Weathermap API
#
# Río Gallegos with city ID:3838859 was found in the Weathermap API
#
# Ancud with city ID:3899695 was found in the Weathermap API
#
# Tessalit with city ID:2449893 was found in the Weathermap API
#
# Ambon City with city ID:1651531 was found in the Weathermap API
#
# Tuim with city ID:1489048 was found in the Weathermap API
#
# Mehamn with city ID:778707 was found in the Weathermap API
#
# Pingliang with city ID:1798760 was found in the Weathermap API
#
# Vestmannaeyjar with city ID:3412093 was found in the Weathermap API
#
# General Roca with city ID:3855065 was found in the Weathermap API
#
# Surab with city ID:1164306 was found in the Weathermap API
#
# Geraldton with city ID:2070998 was found in the Weathermap API
#
# Nālūt with city ID:2214432 was found in the Weathermap API
#
# nalut,ly was not found in the Weathermap API
#
# Fort Atkinson with city ID:5253498 was found in the Weathermap API
#
# Soller with city ID:2510821 was found in the Weathermap API
#
# Vallenar with city ID:3868633 was found in the Weathermap API
#
# Lavrentiya with city ID:4031637 was found in the Weathermap API
#
# Merowe with city ID:370481 was found in the Weathermap API
#
# Caraballeda with city ID:3646767 was found in the Weathermap API
#
# Niono with city ID:2452655 was found in the Weathermap API
#
# Peleduy with city ID:2018069 was found in the Weathermap API
#
# Muros with city ID:3115824 was found in the Weathermap API
#
# Carbonia with city ID:2525362 was found in the Weathermap API
#
# Donskoye with city ID:565289 was found in the Weathermap API
#
# Plettenberg Bay with city ID:964712 was found in the Weathermap API
#
# Bulgan with city ID:2032201 was found in the Weathermap API
#
# Ilhabela with city ID:3461425 was found in the Weathermap API
#
# São João da Barra with city ID:3448903 was found in the Weathermap API
#
# Muncie with city ID:4924006 was found in the Weathermap API
#
# Pacific Grove with city ID:5380437 was found in the Weathermap API
#
# Miraflores with city ID:3674740 was found in the Weathermap API
#
# Virginia Beach with city ID:4791259 was found in the Weathermap API
#
# Bintulu with city ID:1737486 was found in the Weathermap API
#
# Ayorou with city ID:2447416 was found in the Weathermap API
#
# Kaseda-shirakame with city ID:1859964 was found in the Weathermap API
#
# Kotovsk with city ID:543605 was found in the Weathermap API
#
# Kiunga with city ID:2093846 was found in the Weathermap API
#
# Rundu with city ID:3353383 was found in the Weathermap API
#
# Saint Albans with city ID:4820938 was found in the Weathermap API
#
# skalistyy,ru was not found in the Weathermap API
#
# meyungs,pw was not found in the Weathermap API
#
# preobrazhenskaya,ru was not found in the Weathermap API
#
# Berlevåg with city ID:780687 was found in the Weathermap API
#
# Chui with city ID:3443061 was found in the Weathermap API
#
# Enterprise with city ID:5503766 was found in the Weathermap API
#
# Xunchang with city ID:1787901 was found in the Weathermap API
#
# Roboré with city ID:3444176 was found in the Weathermap API
#
# Assiut with city ID:359783 was found in the Weathermap API
#
# Porbandar with city ID:1259395 was found in the Weathermap API
#
# Narsaq with city ID:3421719 was found in the Weathermap API
#
# Uni with city ID:478996 was found in the Weathermap API
#
# Bridgetown with city ID:3374036 was found in the Weathermap API
#
# Neya with city ID:522353 was found in the Weathermap API
#
# airai,pw was not found in the Weathermap API
#
# Kuril'sk with city ID:2123979 was found in the Weathermap API
#
# Barranca with city ID:3946820 was found in the Weathermap API
#
# Vizinga with city ID:473263 was found in the Weathermap API
#
# Warrnambool with city ID:2144528 was found in the Weathermap API
#
# Kasongo-Lunda with city ID:2315026 was found in the Weathermap API
#
# Bershet' with city ID:576745 was found in the Weathermap API
#
# Jardim with city ID:3460087 was found in the Weathermap API
#
# gilazi,az was not found in the Weathermap API
#
# Paita with city ID:3694112 was found in the Weathermap API
#
# Fukuechō with city ID:1863997 was found in the Weathermap API
#
# fukue,jp was not found in the Weathermap API
#
# Shirokiy with city ID:2016680 was found in the Weathermap API
#
# kapoeta,sd was not found in the Weathermap API
#
# Meulaboh with city ID:1214488 was found in the Weathermap API
#
# Nikki with city ID:2392505 was found in the Weathermap API
#
# Menongue with city ID:3347353 was found in the Weathermap API
#
# Palmer with city ID:4946620 was found in the Weathermap API
#
# Ranau with city ID:1733502 was found in the Weathermap API
#
# bolungarvik,is was not found in the Weathermap API
#
# Millinocket with city ID:4972220 was found in the Weathermap API
#
# Great Yarmouth with city ID:2647984 was found in the Weathermap API
# Derzhavīnsk with city ID:1524606 was found in the Weathermap API
#
# derzhavinsk,kz was not found in the Weathermap API
#
# Alice Springs with city ID:2077895 was found in the Weathermap API
#
# Blairmore with city ID:5903535 was found in the Weathermap API
#
# San Cristobal with city ID:3651949 was found in the Weathermap API
#
# Ugoofaaru with city ID:1337619 was found in the Weathermap API
#
# jiddah,sa was not found in the Weathermap API
#
# Makat with city ID:608872 was found in the Weathermap API
#
# Xai-Xai with city ID:1024552 was found in the Weathermap API
#
# Saint-Michel-des-Saints with city ID:6138802 was found in the Weathermap API
#
# Solnechnyy with city ID:2016307 was found in the Weathermap API
#
# sorvag,fo was not found in the Weathermap API
#
# Yong’an with city ID:1806687 was found in the Weathermap API
#
# Half Moon Bay with city ID:5354943 was found in the Weathermap API
#
# avera,pf was not found in the Weathermap API
#
# Deputatsky with city ID:2028164 was found in the Weathermap API
#
# Katsuura with city ID:2112309 was found in the Weathermap API
#
# Hirara with city ID:1862505 was found in the Weathermap API
#
# Pula with city ID:3192224 was found in the Weathermap API
#
# halalo,wf was not found in the Weathermap API
#
# Bāndarban with city ID:1185270 was found in the Weathermap API
#
# bandarban,bd was not found in the Weathermap API
#
# Kavaratti with city ID:1267390 was found in the Weathermap API
#
# juba,sd was not found in the Weathermap API
#
# Hadgāon with city ID:1270554 was found in the Weathermap API
#
# hadgaon,in was not found in the Weathermap API
#
# Cartagena with city ID:3687238 was found in the Weathermap API
#
# Leningradskiy with city ID:2123814 was found in the Weathermap API
#
# Busdi with city ID:1722307 was found in the Weathermap API
#
# Merauke with city ID:2082539 was found in the Weathermap API
#
# Mareeba with city ID:2158767 was found in the Weathermap API
#
# Olavarría with city ID:3842670 was found in the Weathermap API
#
# Pangai with city ID:4032369 was found in the Weathermap API
#
# Pisco with city ID:3932145 was found in the Weathermap API
#
# Turukhansk with city ID:1488903 was found in the Weathermap API
#
# Bengkulu with city ID:1649150 was found in the Weathermap API
#
# Oudtshoorn with city ID:967106 was found in the Weathermap API
#
# Hambantota with city ID:1244926 was found in the Weathermap API
#
# Zonguldak with city ID:737021 was found in the Weathermap API
#
# Ixtapa with city ID:4004293 was found in the Weathermap API
#
# Kiruna with city ID:605155 was found in the Weathermap API
#
# Sørland with city ID:3137469 was found in the Weathermap API
#
# stoyba,ru was not found in the Weathermap API
#
# Harlingen with city ID:2754817 was found in the Weathermap API
#
# japura,br was not found in the Weathermap API
#
# Büdingen with city ID:2942073 was found in the Weathermap API
#
# Pampas with city ID:3933185 was found in the Weathermap API
#
# Westport with city ID:2206900 was found in the Weathermap API
#
# Demirci with city ID:317241 was found in the Weathermap API
#
# Sangar with city ID:2017215 was found in the Weathermap API
#
# Oranjemund with city ID:3354071 was found in the Weathermap API
#
# Tabuk with city ID:101628 was found in the Weathermap API
#
# Bandar-e Lengeh with city ID:141665 was found in the Weathermap API
#
# Atar with city ID:2381334 was found in the Weathermap API
#
# Devin with city ID:732285 was found in the Weathermap API
#
# Hamilton with city ID:3573197 was found in the Weathermap API
#
# Porto Santo with city ID:8010683 was found in the Weathermap API
#
# Ordzhonikidze with city ID:698438 was found in the Weathermap API
#
# Sīrjān with city ID:114259 was found in the Weathermap API
#
# sirjan,ir was not found in the Weathermap API
#
# tabiauea,ki was not found in the Weathermap API
#
# Pangnirtung with city ID:6096551 was found in the Weathermap API
#
# Kalabo with city ID:915471 was found in the Weathermap API
#
# Mendoza with city ID:3844421 was found in the Weathermap API
#
# Mount Isa with city ID:2065594 was found in the Weathermap API
#
# Kirkenes with city ID:779303 was found in the Weathermap API
#
# Batagay-Alyta with city ID:2027042 was found in the Weathermap API
#
# Mount Gambier with city ID:2156643 was found in the Weathermap API
#
# Okakarara with city ID:3354876 was found in the Weathermap API
#
# Bariloche with city ID:7647007 was found in the Weathermap API
#
# Olinda with city ID:3393536 was found in the Weathermap API
#
# Wodonga with city ID:2143285 was found in the Weathermap API
#
# Fairbanks with city ID:5861897 was found in the Weathermap API
#
# Mēga with city ID:331259 was found in the Weathermap API
#
# mega,et was not found in the Weathermap API
#
# Kaeo with city ID:2189343 was found in the Weathermap API
#
# Ust'-Tarka with city ID:1488074 was found in the Weathermap API
#
# San with city ID:2451778 was found in the Weathermap API
#
# Along with city ID:1278969 was found in the Weathermap API
#
# Broken Hill with city ID:2173911 was found in the Weathermap API
#
# Longyearbyen with city ID:2729907 was found in the Weathermap API
#
# Kohat with city ID:1173491 was found in the Weathermap API
#
# Aklavik with city ID:5882953 was found in the Weathermap API
#
# Byron Bay with city ID:2172880 was found in the Weathermap API
#
# Ahipara with city ID:2194098 was found in the Weathermap API
#
# Kutum with city ID:371745 was found in the Weathermap API
#
# Kuytun with city ID:2021093 was found in the Weathermap API
#
# Kayerkan with city ID:1497337 was found in the Weathermap API
#
# warqla,dz was not found in the Weathermap API
#
# nguiu,au was not found in the Weathermap API
#
# Padang with city ID:1633419 was found in the Weathermap API
#
# Hay River with city ID:5972762 was found in the Weathermap API
#
# Kendari with city ID:1640344 was found in the Weathermap API
#
# Russkaya Polyana with city ID:1493423 was found in the Weathermap API
#
# Miepherkeim with city ID:300796 was found in the Weathermap API
#
# Huanren with city ID:2036713 was found in the Weathermap API
#
# Salinópolis with city ID:3389822 was found in the Weathermap API
#
# Malindi with city ID:187968 was found in the Weathermap API
#
# Waingapu with city ID:1622318 was found in the Weathermap API
#
# Skjervøy with city ID:777682 was found in the Weathermap API
#
# Gwadar with city ID:1177446 was found in the Weathermap API
#
# San Jeronimo with city ID:3982846 was found in the Weathermap API
#
# Zhezkazgan with city ID:1516589 was found in the Weathermap API
#
# Carutapera with city ID:3402648 was found in the Weathermap API
#
# tapaua,br was not found in the Weathermap API
#
# Sur with city ID:286245 was found in the Weathermap API
#
# Trincomalee with city ID:1226260 was found in the Weathermap API
#
# Khorinsk with city ID:2022304 was found in the Weathermap API
#
# Havøysund with city ID:779622 was found in the Weathermap API
#
# Bolobo with city ID:2316748 was found in the Weathermap API
#
# Kodinsk with city ID:1503037 was found in the Weathermap API
#
# Belmonte with city ID:3470137 was found in the Weathermap API
#
# Georgiyevka with city ID:1524243 was found in the Weathermap API
#
# Altagracia de Orituco with city ID:3649408 was found in the Weathermap API
#
# Clarence Town with city ID:3572640 was found in the Weathermap API
#
# Nānākuli with city ID:5851349 was found in the Weathermap API
#
# nanakuli,us was not found in the Weathermap API
#
# Camocim with city ID:3403687 was found in the Weathermap API
#
# Blackwater with city ID:2175403 was found in the Weathermap API
#
# Zhigalovo with city ID:2012532 was found in the Weathermap API
#
# tonj,sd was not found in the Weathermap API
#
# Saint Paul Harbor with city ID:5866583 was found in the Weathermap API
#
# Evensk with city ID:2125693 was found in the Weathermap API
#
# Kumluca with city ID:305681 was found in the Weathermap API
#
# Zarubino with city ID:2012646 was found in the Weathermap API
#
# Kamenka with city ID:553766 was found in the Weathermap API
#
# Taoudenni with city ID:2450173 was found in the Weathermap API
#
# Diego de Almagro with city ID:3892454 was found in the Weathermap API
#
# Ternate with city ID:1624041 was found in the Weathermap API
#
# Ankazoabo with city ID:1072879 was found in the Weathermap API
#
# Kostanay with city ID:1519928 was found in the Weathermap API
#
# Vila Franca do Campo with city ID:3372472 was found in the Weathermap API
#
# Tegul'det with city ID:1489822 was found in the Weathermap API
#
# Yamachiche with city ID:6185138 was found in the Weathermap API
# Tuatapere with city ID:2180815 was found in the Weathermap API
#
# Lødingen with city ID:3147102 was found in the Weathermap API
#
# Wajid with city ID:50814 was found in the Weathermap API
#
# Caravelas with city ID:3466980 was found in the Weathermap API
#
# Alta Floresta with city ID:6316343 was found in the Weathermap API
#
# Tual with city ID:1623197 was found in the Weathermap API
#
# Acaraú with city ID:3408368 was found in the Weathermap API
#
# Algiers with city ID:2507480 was found in the Weathermap API
#
# Ormara with city ID:1168700 was found in the Weathermap API
#
# Yumen with city ID:1528998 was found in the Weathermap API
#
# Falmouth with city ID:3490520 was found in the Weathermap API
#
# karamea,nz was not found in the Weathermap API
#
# Varkala with city ID:1253392 was found in the Weathermap API
#
# Seia with city ID:2734215 was found in the Weathermap API
#
# tarudant,ma was not found in the Weathermap API
#
# Mogadishu with city ID:53654 was found in the Weathermap API
#
# khani,ru was not found in the Weathermap API
#
# Antsirabe with city ID:1069166 was found in the Weathermap API
#
# Lupiro with city ID:155584 was found in the Weathermap API
#
# Urla with city ID:298316 was found in the Weathermap API
#
# San Rafael with city ID:3836669 was found in the Weathermap API
#
# Tezu with city ID:1254709 was found in the Weathermap API
#
# Ostrovnoy with city ID:556268 was found in the Weathermap API
#
# Waterloo with city ID:2403094 was found in the Weathermap API
#
# Oyotún with city ID:3694197 was found in the Weathermap API
#
# Nicoya with city ID:3622716 was found in the Weathermap API
#
# Darlawn with city ID:1273463 was found in the Weathermap API
#
# Cairns with city ID:2172797 was found in the Weathermap API
#
# Røros with city ID:3141332 was found in the Weathermap API
#
# Saldanha with city ID:3361934 was found in the Weathermap API
#
# Port Augusta with city ID:2063056 was found in the Weathermap API
#
# Riyadh with city ID:108410 was found in the Weathermap API
#
# Glasgow with city ID:4142683 was found in the Weathermap API
#
# Matamba with city ID:154635 was found in the Weathermap API
#
# Iqaluit with city ID:5983720 was found in the Weathermap API
#
# Mayumba with city ID:2399001 was found in the Weathermap API
#
# Thinadhoo with city ID:1337610 was found in the Weathermap API
#
# St. Marys with city ID:4220629 was found in the Weathermap API
#
# Dicabisagan with city ID:1715015 was found in the Weathermap API
#
# gangotri,in was not found in the Weathermap API
#
# Quesnel with city ID:6115187 was found in the Weathermap API
#
# Moree with city ID:2156927 was found in the Weathermap API
#
# Makokou with city ID:2399371 was found in the Weathermap API
#
# Biasca with city ID:2661524 was found in the Weathermap API
#
# san ignacio,bo was not found in the Weathermap API
#
# Petushki with city ID:509697 was found in the Weathermap API
#
# Sawtell with city ID:2150163 was found in the Weathermap API
#
# Pyra with city ID:503428 was found in the Weathermap API
#
# Puerto Baquerizo Moreno with city ID:3652758 was found in the Weathermap API
#
# Santa Maria with city ID:3374218 was found in the Weathermap API
#
# Naryan-Mar with city ID:523392 was found in the Weathermap API
#
# Trinidad with city ID:3534915 was found in the Weathermap API
#
# Sinjār with city ID:448149 was found in the Weathermap API
#
# sinjar,iq was not found in the Weathermap API
#
# Magnolia with city ID:4120323 was found in the Weathermap API
#
# Chodavaram with city ID:1274020 was found in the Weathermap API
#
# Zhigansk with city ID:2012530 was found in the Weathermap API
#
# Massakory with city ID:2428228 was found in the Weathermap API
#
# Koutiala with city ID:2454268 was found in the Weathermap API
#
# Cockburn Town with city ID:3576994 was found in the Weathermap API
#
# Podosinovets with city ID:508068 was found in the Weathermap API
#
# Talnakh with city ID:1490256 was found in the Weathermap API
#
# Porosozero with city ID:506232 was found in the Weathermap API
#
# Santa Marinella with city ID:3167520 was found in the Weathermap API
#
# Moose Factory with city ID:6078372 was found in the Weathermap API
#
# Cairo with city ID:360630 was found in the Weathermap API
#
# Kirksville with city ID:5055787 was found in the Weathermap API
#
# Samarai with city ID:2132606 was found in the Weathermap API
#
# Barra do Garças with city ID:3470709 was found in the Weathermap API
#
# Honiara with city ID:2108502 was found in the Weathermap API
#
# Gardez with city ID:1141857 was found in the Weathermap API
#
# Qaryat Sulūq with city ID:81604 was found in the Weathermap API
#
# suluq,ly was not found in the Weathermap API
#
# tsihombe,mg was not found in the Weathermap API
#
# raga,sd was not found in the Weathermap API
#
# Troitsko-Pechorsk with city ID:481548 was found in the Weathermap API
#
# Jalu with city ID:86049 was found in the Weathermap API
#
# Malé with city ID:1282027 was found in the Weathermap API
#
# Vao with city ID:2137773 was found in the Weathermap API
#
# Boyolangu with city ID:1648082 was found in the Weathermap API
#
# Inuvik with city ID:5983607 was found in the Weathermap API
#
# Bestöbe with city ID:1525376 was found in the Weathermap API

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a Dictionary from the lists created above

weather_dict = {
    "city_id": city_id,
    "city_name": city_name,
    "country": country,
    "latitude": latitude,
    "longitude": longitude,
    "weather_date": weather_date,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind_speed": wind_speed
}

# Use Dictionary to create DataFrame weather_data

cities_temps_df = pd.DataFrame(weather_dict)
cities_temps_df.head()
# Out:
#      city_id           city_name country  latitude  longitude weather_date  \
# 0  3430443.0            Necochea      AR    -38.55     -58.74     11/09/20
# 1  2077963.0              Albany      AU    -35.02     117.89     11/09/20
# 2  2537881.0                Safi      MA     32.30      -9.24     11/09/20
# 3  3388847.0  São Félix do Xingu      BR     -6.64     -51.99     11/09/20
# 4        NaN                None    None       NaN        NaN         None
#
#     temp  humidity  cloudiness  wind_speed
# 0  79.00      40.0       100.0        8.01
# 1  48.20      93.0        75.0       23.04
# 2  66.29      80.0         0.0       19.28
# 3  89.02      55.0        89.0        4.50
# 4    NaN       NaN         NaN         NaN

# %%
# Save city data into a csv file
cities_temps_df.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# --- find cities that have humidity over 100% ---
humidity_over_100 = cities_temps_df.loc[cities_temps_df["humidity"] > 100, :]

if humidity_over_100.empty == True:
    print("There are no cities with humidity values over 100%")
    print("Using original dataframe to continue with plotting...")
    
    # --- extract relevant fields from the data frame for plotting ---
    latitudes = cities_temps_df["latitude"]
    temperatures = cities_temps_df["temp"]
    humidity = cities_temps_df["humidity"]
    cloudiness = cities_temps_df["cloudiness"]
    windspeed = cities_temps_df["wind_speed"]
    
else:
    # -- get the indices of cities that have humidity over 100% ---
    Humidityover100Index = humidity_over_100.index
    
    # --- create a clean DataFrame by dropping all humidity outliers by index found above ---
    clean_city_data = cities_temps_df.drop(Humidityover100Index).reset_index(drop=True)
    clean_city_data.head()
    
    # --- extract relevant fields from the data frame for plotting ---
    latitudes = clean_city_data["latitude"]
    temperatures = clean_city_data["temp"]
    humidity = clean_city_data["humidity"]
    cloudiness = clean_city_data["cloudiness"]
    windspeed = clean_city_data["wind_speed"]

    # --- export the new dataframe into a csv ---
    clean_city_data.to_csv("../output_data/clean_city_data.csv", index=True, index_label="City ID", header=True)

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot

plt.scatter(weather_dict["latitude"], weather_dict["temp"], facecolor = "blue", edgecolor = "black")

# Set Title

plt.title("Latitude vs. Temperature")

# Set x axis label

plt.xlabel("Laitude")

# Set y axis label

plt.ylabel("Temperature (F)")

# Set grid line

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save plotted figure as .png file

plt.savefig("../images/latitude_temperature_plot.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot

plt.scatter(weather_dict["latitude"], weather_dict["humidity"], facecolor = "blue", edgecolor = "black")

# Set Title

plt.title("Latitude vs. Humidity")

# Set x axis label

plt.xlabel("Laitude")

# Set y axis label

plt.ylabel("Humidity (%)")

# Set grid line

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save plotted figure as .png file

plt.savefig("../images/latitude_humidity_plot.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Coudiness Plot

plt.scatter(weather_dict["latitude"], weather_dict["cloudiness"], facecolor = "blue", edgecolor = "black")

# Set Title

plt.title("Latitude vs. Cloudiness")

# Set x axis label

plt.xlabel("Laitude")

# Set y axis label

plt.ylabel("Cloudiness")

# Set y axis limit

plt.ylim(-2,50)

# Set grid line

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save plotted figure as .png file

plt.savefig("../images/latitude_cloudiness_plot.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed Plot

plt.scatter(weather_dict["latitude"], weather_dict["wind_speed"], facecolor = "blue", edgecolor = "black")

# Set Title

plt.title("Latitude vs. Wind Speed (MPH)")

# Set x axis label

plt.xlabel("Laitude")

# Set y axis label

plt.ylabel("Wind Speed (MPH)")

# Set y axis limit

plt.ylim(-2,50)

# Set grid line

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save plotted figure as .png file

plt.savefig("../images/latitude_Wind_speed_plot.png")

# %% [markdown]
# ## Linear Regression

# %%
# Create DataFrames for Northern and Southern Hemispheres

northern_hemisphere = cities_temps_df.loc[cities_temps_df["latitude"]>0.01]
southern_hemisphere = cities_temps_df.loc[cities_temps_df["latitude"]<-0.01]

# northern_hemisphere.head()

northern_hemisphere.head()

# southern_hemisphere.head()

southern_hemisphere.head()
# Out:
#      city_id           city_name country  latitude  longitude weather_date  \
# 0  3430443.0            Necochea      AR    -38.55     -58.74     11/09/20
# 1  2077963.0              Albany      AU    -35.02     117.89     11/09/20
# 3  3388847.0  São Félix do Xingu      BR     -6.64     -51.99     11/09/20
# 7  2411397.0          Georgetown      SH     -7.93     -14.42     11/09/20
# 9  2206939.0               Bluff      NZ    -46.60     168.33     11/09/20
#
#     temp  humidity  cloudiness  wind_speed
# 0  79.00      40.0       100.0        8.01
# 1  48.20      93.0        75.0       23.04
# 3  89.02      55.0        89.0        4.50
# 7  74.08      77.0         3.0       17.76
# 9  48.99      86.0         2.0        4.00

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Scatter Plot for Northern Hemisphere -- Max Temp vs. Latitude Linear Regression

x_values = northern_hemisphere['latitude']
y_values = northern_hemisphere['temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Northern Hemisphere -- Max Temp vs. Latitude (11/3/2020)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, 80)

plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/temp_lat_lingress.png")
# Out:
# The r-squared is: -0.8607653652790724
# y = -1.11x + 93.96

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Northern Hemisphere -- Humidity (%) vs. Latitude Linear Regression

x_values = northern_hemisphere['latitude']
y_values = northern_hemisphere['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Northern Hemisphere -- Humidity (%) vs. Latitude (11/3/2020)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, 80)

plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/humidity_lat_lingress.png")
# Out:
# The r-squared is: 0.3936183645457845
# y = 0.39x + 57.88

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Southern Hemisphere -- Humidity (%) vs. Latitude Linear Regression

x_values = southern_hemisphere['latitude']
y_values = southern_hemisphere['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Southern Hemisphere -- Humidity (%) vs. Latitude (11/3/2020)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, -50)

plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/sh_humidity_lat_lingress.png")
# Out:
# The r-squared is: 0.2045011066738503
# y = 0.3x + 74.46

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Northern Hemisphere -- Cloudiness (%) vs. Latitude Linear Regression

x_values = northern_hemisphere['latitude']
y_values = northern_hemisphere['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Northern Hemisphere -- Cloudiness (%) vs. Latitude (11/3/2020)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, 80)

plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/cloudiness_lat_lingress.png")
# Out:
# The r-squared is: 0.28550697703346484
# y = 0.54x + 26.15

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Southern Hemisphere: Cloudiness (%) vs. Latitude Linear Regression

x_values = southern_hemisphere['latitude']
y_values = southern_hemisphere['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Southern Hemisphere -- Cloudiness (%) vs. Latitude (11/3/2020)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, -50)

plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/sh_cloudiness_lat_lingress.png")
# Out:
# The r-squared is: 0.25889201293676034
# y = 0.72x + 65.34

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Northern Hemisphere -- Wind Speed (MPH) vs. Latitude Linear Regression

x_values = northern_hemisphere['latitude']
y_values = northern_hemisphere['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Northern Hemisphere -- Wind Speed (MPH) vs. Latitude (11/3/2020)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(0,40)
plt.xlim(0,80)

plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/wind_speed_lat_lingress.png")
# Out:
# The r-squared is: 0.17544505259813184
# y = 0.06x + 6.67

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Southern Hemisphere -- Wind Speed (MPH) vs. Latitude Linear Regression

x_values = southern_hemisphere['latitude']
y_values = southern_hemisphere['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.title("Southern Hemisphere -- Wind Speed (MPH) vs. Latitude (11/3/20)")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-5,10),fontsize=15,color="red")

plt.ylim(0,40)
plt.xlim(0,-60)

plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")
print(line_eq)

plt.savefig("../images/sh_wind_speed_lat_lingress.png")
# Out:
# The r-squared is: -0.16584955231637755
# y = -0.07x + 8.06
