# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time

# Import API key
from config import gkey

# %%
# Import File and Set DataFrame
cities_temps_df = pd.read_csv("../WeatherPy/output_data/cities.csv")
cities_temps_df
# Out:
#        city_id           city_name country  latitude  longitude weather_date  \
# 0    3430443.0            Necochea      AR    -38.55     -58.74     11/09/20
# 1    2077963.0              Albany      AU    -35.02     117.89     11/09/20
# 2    2537881.0                Safi      MA     32.30      -9.24     11/09/20
# 3    3388847.0  São Félix do Xingu      BR     -6.64     -51.99     11/09/20
# 4          NaN                 NaN     NaN       NaN        NaN          NaN
# ..         ...                 ...     ...       ...        ...          ...
# 616  1282027.0                Malé      MV      4.17      73.51     11/09/20
# 617  2137773.0                 Vao      NC    -22.67     167.48     11/09/20
# 618  1648082.0           Boyolangu      ID     -8.12     111.89     11/09/20
# 619  5983607.0              Inuvik      CA     68.35    -133.72     11/09/20
# 620  1525376.0             Bestöbe      KZ     52.50      73.10     11/09/20
#
#       temp  humidity  cloudiness  wind_speed
# 0    79.00      40.0       100.0        8.01
# 1    48.20      93.0        75.0       23.04
# 2    66.29      80.0         0.0       19.28
# 3    89.02      55.0        89.0        4.50
# 4      NaN       NaN         NaN         NaN
# ..     ...       ...         ...         ...
# 616  82.40      83.0        75.0        5.82
# 617  70.09      73.0        55.0       17.40
# 618  75.99      87.0       100.0        3.09
# 619  -3.12      83.0       100.0       11.41
# 620  35.85      85.0       100.0        5.77
#
# [621 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure Gmaps
gmaps.configure(api_key=gkey)

# Use the Lat and Lng as locations
locations = cities_temps_df[["latitude","longitude"]]

#Add Humidity
humidity = cities_temps_df["humidity"]

# %%
# Plot Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)

# Add Heat Layer
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating=False, max_intensity=np.max(humidity), point_radius=3)

fig.add_layer(heat_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-4-141f8bd39da3> in <module>
#       3
#       4 # Add Heat Layer
# ----> 5 heat_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating=False, max_intensity=np.max(humidity), point_radius=3)
#       6
#       7 fig.add_layer(heat_layer)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
# ---> 27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
#      29         return super(LocationArray, self).validate(obj, locations_as_list)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in _validate_latitude(latitude)
#     306         raise InvalidPointException(
#     307             '{} is not a valid latitude. '
# --> 308             'Latitudes must lie between -90 and 90.'.format(latitude)
#     309         )
#     310
#
# InvalidPointException: nan is not a valid latitude. Latitudes must lie between -90 and 90.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the cities with wind speed less than 10 mph, cloudiness equals to 0 and max temp between 60 and 80
narrowed_city_df = cities_temps_df.loc[(cities_temps_df["wind_speed"] <= 10) & (cities_temps_df["cloudiness"] == 0) & \
                                   (cities_temps_df["temp"] >= 70) & (cities_temps_df["temp"] <= 80)].dropna()

narrowed_city_df
# Out:
#        city_id     city_name country  latitude  longitude weather_date   temp  \
# 20   3894426.0     Coyhaique      CL    -45.58     -72.07     11/09/20  71.60
# 54   1253237.0       Verāval      IN     20.90      70.37     11/09/20  78.76
# 126   100926.0         Umluj      SA     25.02      37.27     11/09/20  77.40
# 128  2454955.0      Kolokani      ML     13.57      -8.03     11/09/20  79.47
# 133  1253578.0     Vadlapūdi      IN     14.32      79.80     11/09/20  70.02
# 250  2446796.0         Bilma      NE     18.69      12.92     11/09/20  71.78
# 294  1258406.0         Rāpar      IN     23.57      70.63     11/09/20  77.25
# 311   286621.0       Salalah      OM     17.02      54.09     11/09/20  78.80
# 316  1045114.0     Inhambane      MZ    -23.86      35.38     11/09/20  78.39
# 321  1175712.0        Jiwani      PK     25.05      61.74     11/09/20  77.56
# 368  4820938.0  Saint Albans      US     38.39     -81.84     11/09/20  79.68
# 505  1177446.0        Gwadar      PK     25.12      62.33     11/09/20  76.01
# 510   286245.0           Sur      OM     22.57      59.53     11/09/20  76.08
# 562  2403094.0      Waterloo      SL      8.34     -13.07     11/09/20  79.00
# 570   108410.0        Riyadh      SA     24.69      46.72     11/09/20  77.00
# 594  1274020.0    Chodavaram      IN     17.83      82.95     11/09/20  71.60
#
#      humidity  cloudiness  wind_speed
# 20       33.0         0.0        6.93
# 54       54.0         0.0        2.44
# 126      59.0         0.0        9.40
# 128      17.0         0.0        6.96
# 133      65.0         0.0        6.82
# 250      29.0         0.0        8.48
# 294      28.0         0.0        3.56
# 311      54.0         0.0        4.70
# 316      94.0         0.0        5.82
# 321      84.0         0.0        5.30
# 368      37.0         0.0        1.99
# 505      86.0         0.0        4.79
# 510      74.0         0.0        1.99
# 562      82.0         0.0        3.67
# 570      41.0         0.0        4.70
# 594      88.0         0.0        2.24

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Store Data into Variable hotel_df
hotel_df = pd.DataFrame(cities_temps_df, columns=["city_name", "country", "latitude", "longitude"])

hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#               city_name country  latitude  longitude Hotel Name
# 0              Necochea      AR    -38.55     -58.74
# 1                Albany      AU    -35.02     117.89
# 2                  Safi      MA     32.30      -9.24
# 3    São Félix do Xingu      BR     -6.64     -51.99
# 4                   NaN     NaN       NaN        NaN
# ..                  ...     ...       ...        ...        ...
# 616                Malé      MV      4.17      73.51
# 617                 Vao      NC    -22.67     167.48
# 618           Boyolangu      ID     -8.12     111.89
# 619              Inuvik      CA     68.35    -133.72
# 620             Bestöbe      KZ     52.50      73.10
#
# [621 rows x 5 columns]

# %%
# Base URL
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Establish Params
params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : gkey}

# %%
for index, row in hotel_df.iterrows():
    # Get city_name, latitude, longitude from DataFrame
    lat = row["latitude"]
    lng = row["longitude"]
    city_name = row["city_name"]
    
    # Add Keyword to params dict
    params["location"] = f"{lat},{lng}"

    # Assemble URL and Make API Request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # Extract Results
    results = response['results']
    
    # Save Hotel Name to DataFrame
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    # If no Hotel Available, Show Missing Field
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
    
    # Wait 1 Second to Make Another API Request to Avoid SSL Error
    time.sleep(1)

# Print End of Search once Search is complete
print("-------End of Search-------")
# Out:
# Retrieving Results for Index 0: Necochea.
# Closest hotel in Necochea is Hotel Ñikén Spa & Business Center.
# ------------
# Retrieving Results for Index 1: Albany.
# Closest hotel in Albany is Six Degrees Albany CBD Boutique Hotel.
# ------------
# Retrieving Results for Index 2: Safi.
# Closest hotel in Safi is RIAD LE CHEVAL BLANC - HÔTEL.
# ------------
# Retrieving Results for Index 3: São Félix do Xingu.
# Closest hotel in São Félix do Xingu is Hotel Serrano.
# ------------
# Retrieving Results for Index 4: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 5: Torbay.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 6: San Policarpo.
# Closest hotel in San Policarpo is JM Lodge.
# ------------
# Retrieving Results for Index 7: Georgetown.
# Closest hotel in Georgetown is Royal Air Force Station Ascension.
# ------------
# Retrieving Results for Index 8: Khandyga.
# Closest hotel in Khandyga is Prezidentskaya Gostinitsa.
# ------------
# Retrieving Results for Index 9: Bluff.
# Closest hotel in Bluff is Foveaux Hotel.
# ------------
# Retrieving Results for Index 10: Yellowknife.
# Closest hotel in Yellowknife is The Explorer Hotel.
# ------------
# Retrieving Results for Index 11: Severo-Kuril'sk.
# Closest hotel in Severo-Kuril'sk is Kak Doma.
# ------------
# Retrieving Results for Index 12: Rikitea.
# Closest hotel in Rikitea is Pension Bianca & Benoit.
# ------------
# Retrieving Results for Index 13: Avarua.
# Closest hotel in Avarua is The Rarotongan Beach Resort & Lagoonarium.
# ------------
# Retrieving Results for Index 14: Rocha.
# Closest hotel in Rocha is Casa Rodo 53.
# ------------
# Retrieving Results for Index 15: Birao.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 16: Puerto Madero.
# Closest hotel in Puerto Madero is Mision Surf Mexico.
# ------------
# Retrieving Results for Index 17: Ushuaia.
# Closest hotel in Ushuaia is Hotel Los Yámanas.
# ------------
# Retrieving Results for Index 18: Ribeira Grande.
# Closest hotel in Ribeira Grande is Refúgio.
# ------------
# Retrieving Results for Index 19: Strezhevoy.
# Closest hotel in Strezhevoy is Sibiryachka.
# ------------
# Retrieving Results for Index 20: Coyhaique.
# Closest hotel in Coyhaique is Hotel Dreams de la Patagonia.
# ------------
# Retrieving Results for Index 21: Eureka.
# Closest hotel in Eureka is Best Western Plus Humboldt Bay Inn.
# ------------
# Retrieving Results for Index 22: São Filipe.
# Closest hotel in São Filipe is Hotel Miramar Fogo Brava.
# ------------
# Retrieving Results for Index 23: Coquimbo.
# Closest hotel in Coquimbo is Hotel San Juan.
# ------------
# Retrieving Results for Index 24: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 25: Puerto Ayora.
# Closest hotel in Puerto Ayora is Hotel Fiesta.
# ------------
# Retrieving Results for Index 26: Hilo.
# Closest hotel in Hilo is Hilo Hawaiian Hotel.
# ------------
# Retrieving Results for Index 27: Dikson.
# Closest hotel in Dikson is Sberbank Rossii.
# ------------
# Retrieving Results for Index 28: Busselton.
# Closest hotel in Busselton is Abbey Beach Resort.
# ------------
# Retrieving Results for Index 29: Atuona.
# Closest hotel in Atuona is Hôtel Hiva Oa Hanakee Lodge.
# ------------
# Retrieving Results for Index 30: Saint-Philippe.
# Closest hotel in Saint-Philippe is Les Embruns Du Baril.
# ------------
# Retrieving Results for Index 31: Laguna.
# Closest hotel in Laguna is Laguna Tourist Hotel.
# ------------
# Retrieving Results for Index 32: Kapaa.
# Closest hotel in Kapaa is Hilton Garden Inn Kauai Wailua Bay.
# ------------
# Retrieving Results for Index 33: Babu.
# Closest hotel in Babu is City Convenience Inn Parking Lot.
# ------------
# Retrieving Results for Index 34: Port Elizabeth.
# Closest hotel in Port Elizabeth is Island Way Villa.
# ------------
# Retrieving Results for Index 35: Cape Town.
# Closest hotel in Cape Town is Atlanticview Cape Town Boutique Hotel.
# ------------
# Retrieving Results for Index 36: Bredasdorp.
# Closest hotel in Bredasdorp is Bredasdorp Square.
# ------------
# Retrieving Results for Index 37: Esim.
# Closest hotel in Esim is Ankobra Beach.
# ------------
# Retrieving Results for Index 38: Hermanus.
# Closest hotel in Hermanus is Misty Waves Boutique Hotel.
# ------------
# Retrieving Results for Index 39: Kadaya.
# Closest hotel in Kadaya is Sberbank Rossii.
# ------------
# Retrieving Results for Index 40: Filingué.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 41: Nyimba.
# Closest hotel in Nyimba is Thula Lodge.
# ------------
# Retrieving Results for Index 42: Nikolskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 43: Maniitsoq.
# Closest hotel in Maniitsoq is Hotel Maniitsoq.
# ------------
# Retrieving Results for Index 44: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 45: Pozo Colorado.
# Closest hotel in Pozo Colorado is Hotel Marriot ⭐️⭐️⭐️⭐️.
# ------------
# Retrieving Results for Index 46: Esperance.
# Closest hotel in Esperance is Esperance Chalet Village.
# ------------
# Retrieving Results for Index 47: Kysyl-Syr.
# Closest hotel in Kysyl-Syr is Sberbank Rossii.
# ------------
# Retrieving Results for Index 48: Jamestown.
# Closest hotel in Jamestown is Richards Travel Lodge.
# ------------
# Retrieving Results for Index 49: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 50: Umm Kaddadah.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 51: Churapcha.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 52: Qasigiannguit.
# Closest hotel in Qasigiannguit is Hotel Discobay.
# ------------
# Retrieving Results for Index 53: Nome.
# Closest hotel in Nome is Noxapaga Suites.
# ------------
# Retrieving Results for Index 54: Verāval.
# Closest hotel in Verāval is The Square Somnath.
# ------------
# Retrieving Results for Index 55: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 56: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 57: Terrace.
# Closest hotel in Terrace is Holiday Inn Express & Suites Terrace.
# ------------
# Retrieving Results for Index 58: Reconquista.
# Closest hotel in Reconquista is Grand Hotel.
# ------------
# Retrieving Results for Index 59: Butaritari.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 60: Ponta do Sol.
# Closest hotel in Ponta do Sol is Pousada Green Place.
# ------------
# Retrieving Results for Index 61: Vostok.
# Closest hotel in Vostok is Sberbank Rossii.
# ------------
# Retrieving Results for Index 62: Araceli.
# Closest hotel in Araceli is Arjemarkyza Lodge.
# ------------
# Retrieving Results for Index 63: Sitka.
# Closest hotel in Sitka is Talon Lodge & Spa.
# ------------
# Retrieving Results for Index 64: Juegang.
# Closest hotel in Juegang is Landison Hotel Nantong.
# ------------
# Retrieving Results for Index 65: Te Anau.
# Closest hotel in Te Anau is Distinction Luxmore Hotel Te Anau.
# ------------
# Retrieving Results for Index 66: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 67: Martvili.
# Closest hotel in Martvili is resort martvili.
# ------------
# Retrieving Results for Index 68: Kavieng.
# Closest hotel in Kavieng is Nusa Island Retreat.
# ------------
# Retrieving Results for Index 69: East London.
# Closest hotel in East London is Blue Lagoon Hotel.
# ------------
# Retrieving Results for Index 70: Saskylakh.
# Closest hotel in Saskylakh is Sberbank Rossii.
# ------------
# Retrieving Results for Index 71: Statesville.
# Closest hotel in Statesville is Courtyard by Marriott Statesville Mooresville/Lake Norman.
# ------------
# Retrieving Results for Index 72: La Ronge.
# Closest hotel in La Ronge is La Ronge Hotel & Suites.
# ------------
# Retrieving Results for Index 73: Fortuna.
# Closest hotel in Fortuna is THE REDWOOD RIVERWALK HOTEL.
# ------------
# Retrieving Results for Index 74: Tuktoyaktuk.
# Closest hotel in Tuktoyaktuk is Hunter's B&B.
# ------------
# Retrieving Results for Index 75: Hobart.
# Closest hotel in Hobart is Hotel Grand Chancellor Hobart.
# ------------
# Retrieving Results for Index 76: Mar del Plata.
# Closest hotel in Mar del Plata is NH Gran Hotel Provincial.
# ------------
# Retrieving Results for Index 77: Tazovsky.
# Closest hotel in Tazovsky is ЧУМ HOTEL.
# ------------
# Retrieving Results for Index 78: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 79: Khatanga.
# Closest hotel in Khatanga is Gostinitsa "Zapolyar'ye".
# ------------
# Retrieving Results for Index 80: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 81: Biak.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 82: Castro.
# Closest hotel in Castro is Hotel boutique Palafito del Mar.
# ------------
# Retrieving Results for Index 83: Cherskiy.
# Closest hotel in Cherskiy is Sberbank.
# ------------
# Retrieving Results for Index 84: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 85: Vaini.
# Closest hotel in Vaini is Paradise First Hotel.
# ------------
# Retrieving Results for Index 86: Killybegs.
# Closest hotel in Killybegs is Tara Hotel.
# ------------
# Retrieving Results for Index 87: Promyshlennaya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 88: Vila Velha.
# Closest hotel in Vila Velha is Golden Tulip Porto Vitória.
# ------------
# Retrieving Results for Index 89: Margate.
# Closest hotel in Margate is St Michaels Sands Hotel and Restaurant.
# ------------
# Retrieving Results for Index 90: North Bend.
# Closest hotel in North Bend is Quality Inn & Suites At Coos Bay.
# ------------
# Retrieving Results for Index 91: Dingle.
# Closest hotel in Dingle is Dingle Skellig Hotel.
# ------------
# Retrieving Results for Index 92: Alofi.
# Closest hotel in Alofi is Taloa Heights.
# ------------
# Retrieving Results for Index 93: Lüderitz.
# Closest hotel in Lüderitz is LÜDERITZ NEST HOTEL.
# ------------
# Retrieving Results for Index 94: Punta Arenas.
# Closest hotel in Punta Arenas is Hotel Cabo de Hornos.
# ------------
# Retrieving Results for Index 95: Springdale.
# Closest hotel in Springdale is DoubleTree Club by Hilton Hotel Springdale.
# ------------
# Retrieving Results for Index 96: Isangel.
# Closest hotel in Isangel is Volcano Sea View Tree House.
# ------------
# Retrieving Results for Index 97: Biu.
# Closest hotel in Biu is Biu Luxury Motel and Suites.
# ------------
# Retrieving Results for Index 98: Port Lincoln.
# Closest hotel in Port Lincoln is Marina Hotel.
# ------------
# Retrieving Results for Index 99: Ambilobe.
# Closest hotel in Ambilobe is Hotel National.
# ------------
# Retrieving Results for Index 100: Faanui.
# Closest hotel in Faanui is InterContinental Bora Bora Resort Thalasso Spa.
# ------------
# Retrieving Results for Index 101: Lompoc.
# Closest hotel in Lompoc is Embassy Suites by Hilton Lompoc Central Coast.
# ------------
# Retrieving Results for Index 102: Baykit.
# Closest hotel in Baykit is Sberbank Rossii.
# ------------
# Retrieving Results for Index 103: Chumikan.
# Closest hotel in Chumikan is Fortuna.
# ------------
# Retrieving Results for Index 104: Norman Wells.
# Closest hotel in Norman Wells is Heritage Hotel.
# ------------
# Retrieving Results for Index 105: Carnarvon.
# Closest hotel in Carnarvon is Coral Coast Tourist Park.
# ------------
# Retrieving Results for Index 106: Lang Suan.
# Closest hotel in Lang Suan is บ้านกลางสวนรีสอร์ท.
# ------------
# Retrieving Results for Index 107: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 108: Nanortalik.
# Closest hotel in Nanortalik is Hotel Kap Farvel.
# ------------
# Retrieving Results for Index 109: Darya Khan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 110: Vuktyl.
# Closest hotel in Vuktyl is Mini-Hotel Lokomotiv.
# ------------
# Retrieving Results for Index 111: Nemuro.
# Closest hotel in Nemuro is Hotel Nemuro Kaiyoutei.
# ------------
# Retrieving Results for Index 112: Berdigestyakh.
# Closest hotel in Berdigestyakh is Sberbank Rossii.
# ------------
# Retrieving Results for Index 113: Arraial do Cabo.
# Closest hotel in Arraial do Cabo is Orlanova Boutique Hotel.
# ------------
# Retrieving Results for Index 114: Quatre Cocos.
# Closest hotel in Quatre Cocos is Shangri-La's Le Touessrok Resort & Spa.
# ------------
# Retrieving Results for Index 115: Shestakovo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 116: Prieska.
# Closest hotel in Prieska is Allegro Guest House.
# ------------
# Retrieving Results for Index 117: Broome.
# Closest hotel in Broome is Kimberley Sands Resort.
# ------------
# Retrieving Results for Index 118: Panabá.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 119: Harar.
# Closest hotel in Harar is Sumeya Hotel.
# ------------
# Retrieving Results for Index 120: Edéa.
# Closest hotel in Edéa is Hostellerie de la Sanaga.
# ------------
# Retrieving Results for Index 121: Kenai.
# Closest hotel in Kenai is Kenai Airport Hotel.
# ------------
# Retrieving Results for Index 122: Bandarbeyla.
# Closest hotel in Bandarbeyla is JABIR HOTEL.
# ------------
# Retrieving Results for Index 123: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 124: Lorengau.
# Closest hotel in Lorengau is Lorengau Harbourside Hotel.
# ------------
# Retrieving Results for Index 125: Sobolevo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 126: Umluj.
# Closest hotel in Umluj is HP Red Sea Hotel.
# ------------
# Retrieving Results for Index 127: Riosucio.
# Closest hotel in Riosucio is Hotel Mirador.
# ------------
# Retrieving Results for Index 128: Kolokani.
# Closest hotel in Kolokani is Maimouna sylla.
# ------------
# Retrieving Results for Index 129: Pīpār.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 130: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 131: Ubari.
# Closest hotel in Ubari is فندق أوباري.
# ------------
# Retrieving Results for Index 132: Iquique.
# Closest hotel in Iquique is Hotel Terrado Cavancha.
# ------------
# Retrieving Results for Index 133: Vadlapūdi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 134: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 135: Rehoboth.
# Closest hotel in Rehoboth is Ochsenwagen Hotel Pension.
# ------------
# Retrieving Results for Index 136: Avigliana.
# Closest hotel in Avigliana is Hotel chalet del lago Avigliana.
# ------------
# Retrieving Results for Index 137: Yangjiang.
# Closest hotel in Yangjiang is HUALUXE Yangjiang City Center.
# ------------
# Retrieving Results for Index 138: Thompson.
# Closest hotel in Thompson is Quality Inn & Suites Thompson.
# ------------
# Retrieving Results for Index 139: Aitape.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 140: Maragogi.
# Closest hotel in Maragogi is Hotel Praia Dourada.
# ------------
# Retrieving Results for Index 141: Barrow.
# Closest hotel in Barrow is Top of the World Hotel.
# ------------
# Retrieving Results for Index 142: Mahébourg.
# Closest hotel in Mahébourg is Holiday Inn Mauritius Mon Tresor.
# ------------
# Retrieving Results for Index 143: Cidreira.
# Closest hotel in Cidreira is Hotel Castelo.
# ------------
# Retrieving Results for Index 144: Batatais.
# Closest hotel in Batatais is Castelo Palace Hotel.
# ------------
# Retrieving Results for Index 145: Porto Novo.
# Closest hotel in Porto Novo is Cap-Azul Guesthouse.
# ------------
# Retrieving Results for Index 146: Erzin.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 147: Roald.
# Closest hotel in Roald is Smartrom.
# ------------
# Retrieving Results for Index 148: Port Alfred.
# Closest hotel in Port Alfred is Royal St Andrews Hotel.
# ------------
# Retrieving Results for Index 149: Acapulco de Juárez.
# Closest hotel in Acapulco de Juárez is Hotel Emporio Acapulco.
# ------------
# Retrieving Results for Index 150: Dickinson.
# Closest hotel in Dickinson is Fairfield Inn & Suites by Marriott Houston League City.
# ------------
# Retrieving Results for Index 151: Miyako.
# Closest hotel in Miyako is The Park Hotel Jodogahama.
# ------------
# Retrieving Results for Index 152: Yulara.
# Closest hotel in Yulara is Sails in the Desert.
# ------------
# Retrieving Results for Index 153: Saint George.
# Closest hotel in Saint George is Grotto Bay Beach Resort & Spa.
# ------------
# Retrieving Results for Index 154: Berezniki.
# Closest hotel in Berezniki is Aelita.
# ------------
# Retrieving Results for Index 155: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 156: Touros.
# Closest hotel in Touros is Hotel Vila Gale Touros.
# ------------
# Retrieving Results for Index 157: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 158: Vilhena.
# Closest hotel in Vilhena is Portinari Palace Hotel.
# ------------
# Retrieving Results for Index 159: Clyde River.
# Closest hotel in Clyde River is Naujaaraaluit – Clyde River Hotel.
# ------------
# Retrieving Results for Index 160: Kumul.
# Closest hotel in Kumul is 哈密环球大酒店.
# ------------
# Retrieving Results for Index 161: Rudnyy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 162: Polunochnoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 163: Caluquembe.
# Closest hotel in Caluquembe is Banco BIC - Agência Caluquembe.
# ------------
# Retrieving Results for Index 164: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 165: Mundo Nuevo (Ojo de Agua).
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 166: Takanosu.
# Closest hotel in Takanosu is Sugawarakan.
# ------------
# Retrieving Results for Index 167: Namatanai.
# Closest hotel in Namatanai is Namatanai Hotel.
# ------------
# Retrieving Results for Index 168: Kozan.
# Closest hotel in Kozan is Yaver'in Konağı.
# ------------
# Retrieving Results for Index 169: Emerald.
# Closest hotel in Emerald is Emerald Star Hotel.
# ------------
# Retrieving Results for Index 170: Bemidji.
# Closest hotel in Bemidji is Holiday Inn Express Bemidji.
# ------------
# Retrieving Results for Index 171: Berbera.
# Closest hotel in Berbera is Damal Hotel.
# ------------
# Retrieving Results for Index 172: Ürümqi.
# Closest hotel in Ürümqi is JinJiang International Hotel Urumqi.
# ------------
# Retrieving Results for Index 173: Colares.
# Closest hotel in Colares is Arribas Sintra Hotel.
# ------------
# Retrieving Results for Index 174: Kiama.
# Closest hotel in Kiama is The Sebel Kiama Harbourside.
# ------------
# Retrieving Results for Index 175: Conde.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 176: Yantal'.
# Closest hotel in Yantal' is Sberbank Rossii.
# ------------
# Retrieving Results for Index 177: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 178: Zharkent.
# Closest hotel in Zharkent is гостиница Satti.
# ------------
# Retrieving Results for Index 179: Praia.
# Closest hotel in Praia is Hotel Oasis Atlantico Praiamar.
# ------------
# Retrieving Results for Index 180: Seryshevo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 181: Taltal.
# Closest hotel in Taltal is Hotel- Galería "Las brisas".
# ------------
# Retrieving Results for Index 182: Sola.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 183: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 184: Hasaki.
# Closest hotel in Hasaki is 別邸 海と森.
# ------------
# Retrieving Results for Index 185: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 186: Ilulissat.
# Closest hotel in Ilulissat is Hotel Arctic.
# ------------
# Retrieving Results for Index 187: Raudeberg.
# Closest hotel in Raudeberg is Ulvesund FYR.
# ------------
# Retrieving Results for Index 188: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 189: Port Shepstone.
# Closest hotel in Port Shepstone is Umthunzi Hotel & Conference.
# ------------
# Retrieving Results for Index 190: Hithadhoo.
# Closest hotel in Hithadhoo is Pebbles Inn.
# ------------
# Retrieving Results for Index 191: New Norfolk.
# Closest hotel in New Norfolk is The Woodbridge.
# ------------
# Retrieving Results for Index 192: Lapi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 193: Pontianak.
# Closest hotel in Pontianak is Orchardz Hotel Ayani.
# ------------
# Retrieving Results for Index 194: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 195: Oruro.
# Closest hotel in Oruro is Eden by BlueBay.
# ------------
# Retrieving Results for Index 196: Arlit.
# Closest hotel in Arlit is Hôtel Telwa Bungalow.
# ------------
# Retrieving Results for Index 197: Tarko-Sale.
# Closest hotel in Tarko-Sale is Гостиница "Империя".
# ------------
# Retrieving Results for Index 198: Oussouye.
# Closest hotel in Oussouye is Campement ALULUM.
# ------------
# Retrieving Results for Index 199: Flinders.
# Closest hotel in Flinders is Shellharbour Resort & Conference Centre.
# ------------
# Retrieving Results for Index 200: Hofn.
# Closest hotel in Hofn is Aurora Cabins Höfn Iceland.
# ------------
# Retrieving Results for Index 201: Shediac.
# Closest hotel in Shediac is Seely's Motel.
# ------------
# Retrieving Results for Index 202: Makakilo City.
# Closest hotel in Makakilo City is Marriott's Ko Olina Beach Club.
# ------------
# Retrieving Results for Index 203: Victoria.
# Closest hotel in Victoria is Constance Ephelia Mahé Seychelles.
# ------------
# Retrieving Results for Index 204: Petropavlovsk-Kamchatskiy.
# Closest hotel in Petropavlovsk-Kamchatskiy is Avacha Hotel.
# ------------
# Retrieving Results for Index 205: Beidao.
# Closest hotel in Beidao is Jinjiang Inn Select Tianshui Railway Station Jindu Plaza.
# ------------
# Retrieving Results for Index 206: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 207: Hualmay.
# Closest hotel in Hualmay is Hotel Terrazas Del Mar - Huacho.
# ------------
# Retrieving Results for Index 208: Skellefteå.
# Closest hotel in Skellefteå is Quality Hotel Skellefteå Stadshotell.
# ------------
# Retrieving Results for Index 209: Madang.
# Closest hotel in Madang is Madang Lodge Hotel.
# ------------
# Retrieving Results for Index 210: Dunedin.
# Closest hotel in Dunedin is Scenic Hotel Southern Cross.
# ------------
# Retrieving Results for Index 211: Yamada.
# Closest hotel in Yamada is Hotel Business Inn Yamada.
# ------------
# Retrieving Results for Index 212: Bathsheba.
# Closest hotel in Bathsheba is ECO Lifestyle & Lodge.
# ------------
# Retrieving Results for Index 213: Lázaro Cárdenas.
# Closest hotel in Lázaro Cárdenas is Hotel de Casablanca.
# ------------
# Retrieving Results for Index 214: Kruisfontein.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 215: Republic.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 216: Tasiilaq.
# Closest hotel in Tasiilaq is The Red House.
# ------------
# Retrieving Results for Index 217: Gouyave.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 218: Sampit.
# Closest hotel in Sampit is Aquarius Boutique Hotel Sampit.
# ------------
# Retrieving Results for Index 219: Egvekinot.
# Closest hotel in Egvekinot is Sberbank Rossii.
# ------------
# Retrieving Results for Index 220: Karratha.
# Closest hotel in Karratha is Latitude20 The Dunes Apartments.
# ------------
# Retrieving Results for Index 221: Bambous Virieux.
# Closest hotel in Bambous Virieux is Laguna Beach Hotel & Spa.
# ------------
# Retrieving Results for Index 222: Tempio Pausania.
# Closest hotel in Tempio Pausania is Hotel Pausania Inn.
# ------------
# Retrieving Results for Index 223: Kirakira.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 224: Anloga.
# Closest hotel in Anloga is Bulls and Anchor Inn.
# ------------
# Retrieving Results for Index 225: San Patricio.
# Closest hotel in San Patricio is Posada Pablo de Tarso.
# ------------
# Retrieving Results for Index 226: Komsomol'skiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 227: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 228: Banda Aceh.
# Closest hotel in Banda Aceh is Hermes Palace Hotel Banda Aceh.
# ------------
# Retrieving Results for Index 229: Boa Vista.
# Closest hotel in Boa Vista is Hotel Orla do Rio Branco.
# ------------
# Retrieving Results for Index 230: Bethel.
# Closest hotel in Bethel is Best Western Danbury/Bethel.
# ------------
# Retrieving Results for Index 231: Rairangpur.
# Closest hotel in Rairangpur is Hotel OP Palace.
# ------------
# Retrieving Results for Index 232: Tiksi.
# Closest hotel in Tiksi is Arktika.
# ------------
# Retrieving Results for Index 233: Manjeshwar.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 234: Zyryanka.
# Closest hotel in Zyryanka is Zyryanka.
# ------------
# Retrieving Results for Index 235: Pincher Creek.
# Closest hotel in Pincher Creek is Heritage Inn Hotel & Convention Centre.
# ------------
# Retrieving Results for Index 236: Svetlaya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 237: Riohacha.
# Closest hotel in Riohacha is LagunaSalá ByFsl Hostel.
# ------------
# Retrieving Results for Index 238: Jacareacanga.
# Closest hotel in Jacareacanga is HOTEL VIANA.
# ------------
# Retrieving Results for Index 239: Barsovo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 240: College.
# Closest hotel in College is Pike's Waterfront Lodge.
# ------------
# Retrieving Results for Index 241: Kommunarka.
# Closest hotel in Kommunarka is Отель Планет.
# ------------
# Retrieving Results for Index 242: Provideniya.
# Closest hotel in Provideniya is Sberbank Rossii.
# ------------
# Retrieving Results for Index 243: Khāsh.
# Closest hotel in Khāsh is بانک تجارت.
# ------------
# Retrieving Results for Index 244: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 245: Srednekolymsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 246: Nouakchott.
# Closest hotel in Nouakchott is AZALAÏ HOTEL NOUAKCHOTT (MARHABA ).
# ------------
# Retrieving Results for Index 247: Kahului.
# Closest hotel in Kahului is Maui Beach Hotel.
# ------------
# Retrieving Results for Index 248: Malim.
# Closest hotel in Malim is JABOC PLACE INN.
# ------------
# Retrieving Results for Index 249: Nishihara.
# Closest hotel in Nishihara is 百名伽藍.
# ------------
# Retrieving Results for Index 250: Bilma.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 251: Qaanaaq.
# Closest hotel in Qaanaaq is Qaanaaq Hotel.
# ------------
# Retrieving Results for Index 252: Port Blair.
# Closest hotel in Port Blair is Symphony Samudra, Port Blair.
# ------------
# Retrieving Results for Index 253: Portland.
# Closest hotel in Portland is Seascape Accommodation.
# ------------
# Retrieving Results for Index 254: Grindavik.
# Closest hotel in Grindavik is Harbour View.
# ------------
# Retrieving Results for Index 255: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 256: Kupang.
# Closest hotel in Kupang is ASTON Kupang Hotel & Convention Center.
# ------------
# Retrieving Results for Index 257: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 258: Caucayá.
# Closest hotel in Caucayá is la casona de juancho.
# ------------
# Retrieving Results for Index 259: Joshīmath.
# Closest hotel in Joshīmath is Blue Poppy Resorts.
# ------------
# Retrieving Results for Index 260: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 261: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 262: Yar-Sale.
# Closest hotel in Yar-Sale is Hotel "Nord House".
# ------------
# Retrieving Results for Index 263: Linhares.
# Closest hotel in Linhares is Hotel BHS.
# ------------
# Retrieving Results for Index 264: Talcahuano.
# Closest hotel in Talcahuano is Hotel Düsseldorf.
# ------------
# Retrieving Results for Index 265: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 266: Nara.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 267: Smidovich.
# Closest hotel in Smidovich is Coffee Time.
# ------------
# Retrieving Results for Index 268: Pevek.
# Closest hotel in Pevek is Munitsipal'naya Gostinitsa.
# ------------
# Retrieving Results for Index 269: Kaitangata.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 270: Tokur.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 271: Aktobe.
# Closest hotel in Aktobe is The Amsterdam Hotel.
# ------------
# Retrieving Results for Index 272: Buraidah.
# Closest hotel in Buraidah is Ewaa Express Hotel - Buraydah.
# ------------
# Retrieving Results for Index 273: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 274: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 275: Błonie.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 276: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 277: Lebu.
# Closest hotel in Lebu is Hotel Plaza Lebu.
# ------------
# Retrieving Results for Index 278: Mossamedes.
# Closest hotel in Mossamedes is Infotur Namibe.
# ------------
# Retrieving Results for Index 279: Gigmoto.
# Closest hotel in Gigmoto is Cj's Travellers Inn.
# ------------
# Retrieving Results for Index 280: Viedma.
# Closest hotel in Viedma is Hotel Austral Viedma.
# ------------
# Retrieving Results for Index 281: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 282: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 283: Cayenne.
# Closest hotel in Cayenne is Royal Amazonia.
# ------------
# Retrieving Results for Index 284: Constitucion.
# Closest hotel in Constitucion is Hotel Gobernador.
# ------------
# Retrieving Results for Index 285: Jurm.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 286: Bermeo.
# Closest hotel in Bermeo is Gametxo hotela.
# ------------
# Retrieving Results for Index 287: Kalmunai.
# Closest hotel in Kalmunai is LUXEZ garden house.
# ------------
# Retrieving Results for Index 288: Paamiut.
# Closest hotel in Paamiut is Hotel Ivaana.
# ------------
# Retrieving Results for Index 289: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 290: Challapata.
# Closest hotel in Challapata is Alojamiento universal.
# ------------
# Retrieving Results for Index 291: Rio Grande.
# Closest hotel in Rio Grande is Laghetto Viverone Rio Grande.
# ------------
# Retrieving Results for Index 292: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 293: Pandan.
# Closest hotel in Pandan is Bonifacio Lodge.
# ------------
# Retrieving Results for Index 294: Rāpar.
# Closest hotel in Rāpar is Government Guest House.
# ------------
# Retrieving Results for Index 295: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 296: Kyren.
# Closest hotel in Kyren is Tunka-350.
# ------------
# Retrieving Results for Index 297: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 298: Camopi.
# Closest hotel in Camopi is Post Office.
# ------------
# Retrieving Results for Index 299: Saint-Lô.
# Closest hotel in Saint-Lô is Château D'agneaux.
# ------------
# Retrieving Results for Index 300: El Centro.
# Closest hotel in El Centro is Hampton Inn El Centro.
# ------------
# Retrieving Results for Index 301: Kristinestad.
# Closest hotel in Kristinestad is Hotel Alma.
# ------------
# Retrieving Results for Index 302: Cabo San Lucas.
# Closest hotel in Cabo San Lucas is Waldorf Astoria Los Cabos Pedregal.
# ------------
# Retrieving Results for Index 303: Nuquí.
# Closest hotel in Nuquí is Hotel Nuquimar.
# ------------
# Retrieving Results for Index 304: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 305: Kisangani.
# Closest hotel in Kisangani is Les Chalets.
# ------------
# Retrieving Results for Index 306: Praia da Vitória.
# Closest hotel in Praia da Vitória is Atlântida Mar Hotel.
# ------------
# Retrieving Results for Index 307: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 308: Liseleje.
# Closest hotel in Liseleje is Hotel Frederiksværk.
# ------------
# Retrieving Results for Index 309: Honningsvåg.
# Closest hotel in Honningsvåg is Scandic Bryggen.
# ------------
# Retrieving Results for Index 310: San Quintín.
# Closest hotel in San Quintín is Old Mill Hotel.
# ------------
# Retrieving Results for Index 311: Salalah.
# Closest hotel in Salalah is Al Dyafa Hotel Suites.
# ------------
# Retrieving Results for Index 312: Chokurdakh.
# Closest hotel in Chokurdakh is Sberbank Rossii.
# ------------
# Retrieving Results for Index 313: Ben Gardane.
# Closest hotel in Ben Gardane is hotel rayes.
# ------------
# Retrieving Results for Index 314: Vardø.
# Closest hotel in Vardø is Vardø Hotel AS.
# ------------
# Retrieving Results for Index 315: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 316: Inhambane.
# Closest hotel in Inhambane is Hotel Casa Do Capitão.
# ------------
# Retrieving Results for Index 317: Lyuban'.
# Closest hotel in Lyuban' is Ruyes Rup Beltelekom.
# ------------
# Retrieving Results for Index 318: Brae.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 319: Minas.
# Closest hotel in Minas is San Francisco de las Sierras.
# ------------
# Retrieving Results for Index 320: Upernavik.
# Closest hotel in Upernavik is Café de Upernavik.
# ------------
# Retrieving Results for Index 321: Jiwani.
# Closest hotel in Jiwani is Victoria Hut.
# ------------
# Retrieving Results for Index 322: Grand Gaube.
# Closest hotel in Grand Gaube is LUX Grand Gaube Resort & Villas.
# ------------
# Retrieving Results for Index 323: Sept-Îles.
# Closest hotel in Sept-Îles is Château Arnaud.
# ------------
# Retrieving Results for Index 324: Auki.
# Closest hotel in Auki is Auki Lodge.
# ------------
# Retrieving Results for Index 325: Haines Junction.
# Closest hotel in Haines Junction is Alcan Motor Inn.
# ------------
# Retrieving Results for Index 326: Rawson.
# Closest hotel in Rawson is Hotel Punta León.
# ------------
# Retrieving Results for Index 327: Pringsewu.
# Closest hotel in Pringsewu is Urban Style by Front One.
# ------------
# Retrieving Results for Index 328: Villarrica.
# Closest hotel in Villarrica is Hotel Terraza Suite.
# ------------
# Retrieving Results for Index 329: Kalawit.
# Closest hotel in Kalawit is haus am see resort & hotel.
# ------------
# Retrieving Results for Index 330: Río Gallegos.
# Closest hotel in Río Gallegos is Hotel Aire de Patagonia.
# ------------
# Retrieving Results for Index 331: Ancud.
# Closest hotel in Ancud is Panamericana Hotel Ancud.
# ------------
# Retrieving Results for Index 332: Tessalit.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 333: Ambon City.
# Closest hotel in Ambon City is Manise Hotel.
# ------------
# Retrieving Results for Index 334: Tuim.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 335: Mehamn.
# Closest hotel in Mehamn is Mehamn Arctic Hotel AS.
# ------------
# Retrieving Results for Index 336: Pingliang.
# Closest hotel in Pingliang is Jinjiang Inn Pingliang West Station Xuanhe New City.
# ------------
# Retrieving Results for Index 337: Vestmannaeyjar.
# Closest hotel in Vestmannaeyjar is Hotel Vestmannaeyjar.
# ------------
# Retrieving Results for Index 338: General Roca.
# Closest hotel in General Roca is Estepa Hotel.
# ------------
# Retrieving Results for Index 339: Surab.
# Closest hotel in Surab is Muslim Rent Rooms.
# ------------
# Retrieving Results for Index 340: Geraldton.
# Closest hotel in Geraldton is Ocean Centre Hotel.
# ------------
# Retrieving Results for Index 341: Nālūt.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 342: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 343: Fort Atkinson.
# Closest hotel in Fort Atkinson is Country Inn & Suites by Radisson, Ft. Atkinson, WI.
# ------------
# Retrieving Results for Index 344: Soller.
# Closest hotel in Soller is Bikini Island & Mountain Hotels.
# ------------
# Retrieving Results for Index 345: Vallenar.
# Closest hotel in Vallenar is Cabañas Del Frances.
# ------------
# Retrieving Results for Index 346: Lavrentiya.
# Closest hotel in Lavrentiya is Sberbank Rossii.
# ------------
# Retrieving Results for Index 347: Merowe.
# Closest hotel in Merowe is Merowe Tourist Village.
# ------------
# Retrieving Results for Index 348: Caraballeda.
# Closest hotel in Caraballeda is Hotel 15 Letras.
# ------------
# Retrieving Results for Index 349: Niono.
# Closest hotel in Niono is Hôtel Campement.
# ------------
# Retrieving Results for Index 350: Peleduy.
# Closest hotel in Peleduy is Sberbank Rossii.
# ------------
# Retrieving Results for Index 351: Muros.
# Closest hotel in Muros is O Prouso.
# ------------
# Retrieving Results for Index 352: Carbonia.
# Closest hotel in Carbonia is Lu 'Hotel.
# ------------
# Retrieving Results for Index 353: Donskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 354: Plettenberg Bay.
# Closest hotel in Plettenberg Bay is The Plettenberg Hotel.
# ------------
# Retrieving Results for Index 355: Bulgan.
# Closest hotel in Bulgan is Bulgan Hotel.
# ------------
# Retrieving Results for Index 356: Ilhabela.
# Closest hotel in Ilhabela is VELINN Hotel Maison Joly.
# ------------
# Retrieving Results for Index 357: São João da Barra.
# Closest hotel in São João da Barra is OYO Pousada Mediterrâneo.
# ------------
# Retrieving Results for Index 358: Muncie.
# Closest hotel in Muncie is Courtyard by Marriott Muncie at Horizon Convention Center.
# ------------
# Retrieving Results for Index 359: Pacific Grove.
# Closest hotel in Pacific Grove is Monterey Plaza Hotel & Spa.
# ------------
# Retrieving Results for Index 360: Miraflores.
# Closest hotel in Miraflores is Miraflores.
# ------------
# Retrieving Results for Index 361: Virginia Beach.
# Closest hotel in Virginia Beach is The Cavalier Virginia Beach, Autograph Collection.
# ------------
# Retrieving Results for Index 362: Bintulu.
# Closest hotel in Bintulu is GoldenBay Hotel Bintulu.
# ------------
# Retrieving Results for Index 363: Ayorou.
# Closest hotel in Ayorou is Hotel Amenokal.
# ------------
# Retrieving Results for Index 364: Kaseda-shirakame.
# Closest hotel in Kaseda-shirakame is Yoshiya.
# ------------
# Retrieving Results for Index 365: Kotovsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 366: Kiunga.
# Closest hotel in Kiunga is Cassowary Hotel.
# ------------
# Retrieving Results for Index 367: Rundu.
# Closest hotel in Rundu is Hakusembe River Lodge.
# ------------
# Retrieving Results for Index 368: Saint Albans.
# Closest hotel in Saint Albans is Sleep Inn & Suites Cross Lanes - South Charleston.
# ------------
# Retrieving Results for Index 369: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 370: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 371: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 372: Berlevåg.
# Closest hotel in Berlevåg is Berlevåg camping & Appartement AS.
# ------------
# Retrieving Results for Index 373: Chui.
# Closest hotel in Chui is Turis Firper Hotel.
# ------------
# Retrieving Results for Index 374: Enterprise.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 375: Xunchang.
# Closest hotel in Xunchang is Bodu Hotel.
# ------------
# Retrieving Results for Index 376: Roboré.
# Closest hotel in Roboré is Hotel La Casona De Don Pepe.
# ------------
# Retrieving Results for Index 377: Assiut.
# Closest hotel in Assiut is Florence Hotel Assiut.
# ------------
# Retrieving Results for Index 378: Porbandar.
# Closest hotel in Porbandar is Lords Inn Porbandar.
# ------------
# Retrieving Results for Index 379: Narsaq.
# Closest hotel in Narsaq is Hotel Narsaq.
# ------------
# Retrieving Results for Index 380: Uni.
# Closest hotel in Uni is Гостиница «Диалог».
# ------------
# Retrieving Results for Index 381: Bridgetown.
# Closest hotel in Bridgetown is South Gap Hotel.
# ------------
# Retrieving Results for Index 382: Neya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 383: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 384: Kuril'sk.
# Closest hotel in Kuril'sk is гостиница "Итуруп".
# ------------
# Retrieving Results for Index 385: Barranca.
# Closest hotel in Barranca is Hotel Chavin.
# ------------
# Retrieving Results for Index 386: Vizinga.
# Closest hotel in Vizinga is Gostinitsa "Nadezhda".
# ------------
# Retrieving Results for Index 387: Warrnambool.
# Closest hotel in Warrnambool is Deep Blue Hotel & Hot Springs.
# ------------
# Retrieving Results for Index 388: Kasongo-Lunda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 389: Bershet'.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 390: Jardim.
# Closest hotel in Jardim is Vitória Hotel.
# ------------
# Retrieving Results for Index 391: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 392: Paita.
# Closest hotel in Paita is Hotel Buongiorno.
# ------------
# Retrieving Results for Index 393: Fukuechō.
# Closest hotel in Fukuechō is Campana Hotel.
# ------------
# Retrieving Results for Index 394: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 395: Shirokiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 396: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 397: Meulaboh.
# Closest hotel in Meulaboh is Hotel Meuligoe.
# ------------
# Retrieving Results for Index 398: Nikki.
# Closest hotel in Nikki is Hotel John.
# ------------
# Retrieving Results for Index 399: Menongue.
# Closest hotel in Menongue is Ritz Lauca.
# ------------
# Retrieving Results for Index 400: Palmer.
# Closest hotel in Palmer is The Trainmaster's Inn.
# ------------
# Retrieving Results for Index 401: Ranau.
# Closest hotel in Ranau is Inap Desa Kilimu.
# ------------
# Retrieving Results for Index 402: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 403: Millinocket.
# Closest hotel in Millinocket is Katahdin Inn & Suites.
# ------------
# Retrieving Results for Index 404: Great Yarmouth.
# Closest hotel in Great Yarmouth is Gable End Hotel.
# ------------
# Retrieving Results for Index 405: Derzhavīnsk.
# Closest hotel in Derzhavīnsk is Gostinitsa "Ishim".
# ------------
# Retrieving Results for Index 406: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 407: Alice Springs.
# Closest hotel in Alice Springs is DoubleTree by Hilton Hotel Alice Springs.
# ------------
# Retrieving Results for Index 408: Blairmore.
# Closest hotel in Blairmore is Cosmopolitan Hotel & Cozy Corner.
# ------------
# Retrieving Results for Index 409: San Cristobal.
# Closest hotel in San Cristobal is Casa Blanca.
# ------------
# Retrieving Results for Index 410: Ugoofaaru.
# Closest hotel in Ugoofaaru is Ungoofaaru Inn.
# ------------
# Retrieving Results for Index 411: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 412: Makat.
# Closest hotel in Makat is Umit.
# ------------
# Retrieving Results for Index 413: Xai-Xai.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 414: Saint-Michel-des-Saints.
# Closest hotel in Saint-Michel-des-Saints is Hotel Central.
# ------------
# Retrieving Results for Index 415: Solnechnyy.
# Closest hotel in Solnechnyy is Hotel complex Pastoral.
# ------------
# Retrieving Results for Index 416: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 417: Yong’an.
# Closest hotel in Yong’an is Hunyuan shangyuan hotel.
# ------------
# Retrieving Results for Index 418: Half Moon Bay.
# Closest hotel in Half Moon Bay is Beach House - Half Moon Bay.
# ------------
# Retrieving Results for Index 419: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 420: Deputatsky.
# Closest hotel in Deputatsky is Sberbank Rossii.
# ------------
# Retrieving Results for Index 421: Katsuura.
# Closest hotel in Katsuura is Katsuura Hilltop Hotel & Residence.
# ------------
# Retrieving Results for Index 422: Hirara.
# Closest hotel in Hirara is Grand Bleu Gamin.
# ------------
# Retrieving Results for Index 423: Pula.
# Closest hotel in Pula is Park Plaza Histria Pula.
# ------------
# Retrieving Results for Index 424: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 425: Bāndarban.
# Closest hotel in Bāndarban is Nilachol Nilambori Resort.
# ------------
# Retrieving Results for Index 426: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 427: Kavaratti.
# Closest hotel in Kavaratti is Bismillah Hotel And Lodging.
# ------------
# Retrieving Results for Index 428: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 429: Hadgāon.
# Closest hotel in Hadgāon is Jay Maharashtra Hotel.
# ------------
# Retrieving Results for Index 430: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 431: Cartagena.
# Closest hotel in Cartagena is Bastión Luxury Hotel.
# ------------
# Retrieving Results for Index 432: Leningradskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 433: Busdi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 434: Merauke.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 435: Mareeba.
# Closest hotel in Mareeba is The Cape Gateway Motel.
# ------------
# Retrieving Results for Index 436: Olavarría.
# Closest hotel in Olavarría is Savoy Hotel, Olavarría.
# ------------
# Retrieving Results for Index 437: Pangai.
# Closest hotel in Pangai is Ha'apai Beach Resort.
# ------------
# Retrieving Results for Index 438: Pisco.
# Closest hotel in Pisco is Hostal El Candelabro.
# ------------
# Retrieving Results for Index 439: Turukhansk.
# Closest hotel in Turukhansk is ООО "Туруханская пушнина".
# ------------
# Retrieving Results for Index 440: Bengkulu.
# Closest hotel in Bengkulu is Mercure Bengkulu.
# ------------
# Retrieving Results for Index 441: Oudtshoorn.
# Closest hotel in Oudtshoorn is Protea Hotel by Marriott Oudtshoorn Riempie Estate.
# ------------
# Retrieving Results for Index 442: Hambantota.
# Closest hotel in Hambantota is Jade Green Hotel Hambantota.
# ------------
# Retrieving Results for Index 443: Zonguldak.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 444: Ixtapa.
# Closest hotel in Ixtapa is Flamingo Vallarta Hotel & Marina.
# ------------
# Retrieving Results for Index 445: Kiruna.
# Closest hotel in Kiruna is Camp Ripan.
# ------------
# Retrieving Results for Index 446: Sørland.
# Closest hotel in Sørland is Lofoten Værøy Brygge.
# ------------
# Retrieving Results for Index 447: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 448: Harlingen.
# Closest hotel in Harlingen is Anna Casparii.
# ------------
# Retrieving Results for Index 449: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 450: Büdingen.
# Closest hotel in Büdingen is Hotel Saline Superior.
# ------------
# Retrieving Results for Index 451: Pampas.
# Closest hotel in Pampas is ALEX.
# ------------
# Retrieving Results for Index 452: Westport.
# Closest hotel in Westport is The Art Hotel Westport.
# ------------
# Retrieving Results for Index 453: Demirci.
# Closest hotel in Demirci is Sungur Otel.
# ------------
# Retrieving Results for Index 454: Sangar.
# Closest hotel in Sangar is Sberbank.
# ------------
# Retrieving Results for Index 455: Oranjemund.
# Closest hotel in Oranjemund is Oryx Guesthouse Oranjemund.
# ------------
# Retrieving Results for Index 456: Tabuk.
# Closest hotel in Tabuk is Hilton Garden Inn Tabuk.
# ------------
# Retrieving Results for Index 457: Bandar-e Lengeh.
# Closest hotel in Bandar-e Lengeh is Diplomat Hotel.
# ------------
# Retrieving Results for Index 458: Atar.
# Closest hotel in Atar is Bab Sahara.
# ------------
# Retrieving Results for Index 459: Devin.
# Closest hotel in Devin is Исмена СПА Хотел — Ismena SPA Hotel.
# ------------
# Retrieving Results for Index 460: Hamilton.
# Closest hotel in Hamilton is Azura Bermuda.
# ------------
# Retrieving Results for Index 461: Porto Santo.
# Closest hotel in Porto Santo is Hotel Porto Santo & Spa.
# ------------
# ...
# Closest hotel in Kalabo is Sikakubete Guest House Kalabo Town Council.
# ------------
# Retrieving Results for Index 468: Mendoza.
# Closest hotel in Mendoza is Park Hyatt Mendoza.
# ------------
# Retrieving Results for Index 469: Mount Isa.
# Closest hotel in Mount Isa is ibis Styles Mt Isa Verona.
# ------------
# Retrieving Results for Index 470: Kirkenes.
# Closest hotel in Kirkenes is Thon Hotel Kirkenes.
# ------------
# Retrieving Results for Index 471: Batagay-Alyta.
# Closest hotel in Batagay-Alyta is Batagay-Alyta.
# ------------
# Retrieving Results for Index 472: Mount Gambier.
# Closest hotel in Mount Gambier is Commodore on the Park.
# ------------
# Retrieving Results for Index 473: Okakarara.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 474: Bariloche.
# Closest hotel in Bariloche is Le Charme.
# ------------
# Retrieving Results for Index 475: Olinda.
# Closest hotel in Olinda is Pousada do Amparo.
# ------------
# Retrieving Results for Index 476: Wodonga.
# Closest hotel in Wodonga is CIRCA 1928 - a spa hotel.
# ------------
# Retrieving Results for Index 477: Fairbanks.
# Closest hotel in Fairbanks is Bridgewater Hotel.
# ------------
# Retrieving Results for Index 478: Mēga.
# Closest hotel in Mēga is Mega Beteseb Hotel.
# ------------
# Retrieving Results for Index 479: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 480: Kaeo.
# Closest hotel in Kaeo is Pacific Harbour Lodge.
# ------------
# Retrieving Results for Index 481: Ust'-Tarka.
# Closest hotel in Ust'-Tarka is Pearl of Siberia.
# ------------
# Retrieving Results for Index 482: San.
# Closest hotel in San is Hotel Santoro.
# ------------
# Retrieving Results for Index 483: Along.
# Closest hotel in Along is OYO 66194 Hotel Veggie Aman.
# ------------
# Retrieving Results for Index 484: Broken Hill.
# Closest hotel in Broken Hill is Royal Exchange Hotel.
# ------------
# Retrieving Results for Index 485: Longyearbyen.
# Closest hotel in Longyearbyen is Radisson Blu Polar Hotel, Spitsbergen.
# ------------
# Retrieving Results for Index 486: Kohat.
# Closest hotel in Kohat is The City Lodge Guest House.
# ------------
# Retrieving Results for Index 487: Aklavik.
# Closest hotel in Aklavik is Sundog Inn.
# ------------
# Retrieving Results for Index 488: Byron Bay.
# Closest hotel in Byron Bay is Elements of Byron.
# ------------
# Retrieving Results for Index 489: Ahipara.
# Closest hotel in Ahipara is Endless Summer Lodge - Guest House.
# ------------
# Retrieving Results for Index 490: Kutum.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 491: Kuytun.
# Closest hotel in Kuytun is Zhemchug.
# ------------
# Retrieving Results for Index 492: Kayerkan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 493: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 494: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 495: Padang.
# Closest hotel in Padang is d'Ox Ville Hotel.
# ------------
# Retrieving Results for Index 496: Hay River.
# Closest hotel in Hay River is Ptarmigan Inn Hotels.
# ------------
# Retrieving Results for Index 497: Kendari.
# Closest hotel in Kendari is Claro Hotel Kendari.
# ------------
# Retrieving Results for Index 498: Russkaya Polyana.
# Closest hotel in Russkaya Polyana is Лагуна.
# ------------
# Retrieving Results for Index 499: Miepherkeim.
# Closest hotel in Miepherkeim is İkbal otel.
# ------------
# Retrieving Results for Index 500: Huanren.
# Closest hotel in Huanren is Zhengfang Hotel （West Gate）.
# ------------
# Retrieving Results for Index 501: Salinópolis.
# Closest hotel in Salinópolis is Hotel Concha do Mar.
# ------------
# Retrieving Results for Index 502: Malindi.
# Closest hotel in Malindi is Diamonds Dream of Africa.
# ------------
# Retrieving Results for Index 503: Waingapu.
# Closest hotel in Waingapu is Padadita Beach Hotel.
# ------------
# Retrieving Results for Index 504: Skjervøy.
# Closest hotel in Skjervøy is Hotel Maritim Skjervøy AS.
# ------------
# Retrieving Results for Index 505: Gwadar.
# Closest hotel in Gwadar is Zaver Pearl Continental Hotel.
# ------------
# Retrieving Results for Index 506: San Jeronimo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 507: Zhezkazgan.
# Closest hotel in Zhezkazgan is Kosmos.
# ------------
# Retrieving Results for Index 508: Carutapera.
# Closest hotel in Carutapera is HOTEL R. SOARES.
# ------------
# Retrieving Results for Index 509: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 510: Sur.
# Closest hotel in Sur is Sur Plaza Hotel.
# ------------
# Retrieving Results for Index 511: Trincomalee.
# Closest hotel in Trincomalee is Welcombe Hotel.
# ------------
# Retrieving Results for Index 512: Khorinsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 513: Havøysund.
# Closest hotel in Havøysund is Havøysund Hotel & Rorbuer.
# ------------
# Retrieving Results for Index 514: Bolobo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 515: Kodinsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 516: Belmonte.
# Closest hotel in Belmonte is Pousada Caçari.
# ------------
# Retrieving Results for Index 517: Georgiyevka.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 518: Altagracia de Orituco.
# Closest hotel in Altagracia de Orituco is Hacienda la Quinta.
# ------------
# Retrieving Results for Index 519: Clarence Town.
# Closest hotel in Clarence Town is Harbor Breeze Villas.
# ------------
# Retrieving Results for Index 520: Nānākuli.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 521: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 522: Camocim.
# Closest hotel in Camocim is Villa del Mar Praia Hotel.
# ------------
# Retrieving Results for Index 523: Blackwater.
# Closest hotel in Blackwater is The Capricorn Hotel.
# ------------
# Retrieving Results for Index 524: Zhigalovo.
# Closest hotel in Zhigalovo is Gostinitsa "Imperiya".
# ------------
# Retrieving Results for Index 525: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 526: Saint Paul Harbor.
# Closest hotel in Saint Paul Harbor is Best Western Kodiak Inn and Convention Center.
# ------------
# Retrieving Results for Index 527: Evensk.
# Closest hotel in Evensk is Sberbank Rossii.
# ------------
# Retrieving Results for Index 528: Kumluca.
# Closest hotel in Kumluca is TurkuazKöy.
# ------------
# Retrieving Results for Index 529: Zarubino.
# Closest hotel in Zarubino is The recreation center "Lepota".
# ------------
# Retrieving Results for Index 530: Kamenka.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 531: Taoudenni.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 532: Diego de Almagro.
# Closest hotel in Diego de Almagro is hotel luna del desierto.
# ------------
# Retrieving Results for Index 533: Ternate.
# Closest hotel in Ternate is Grand Dafam Bela Ternate.
# ------------
# Retrieving Results for Index 534: Ankazoabo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 535: Kostanay.
# Closest hotel in Kostanay is Gostinitsa Tobyl.
# ------------
# Retrieving Results for Index 536: Vila Franca do Campo.
# Closest hotel in Vila Franca do Campo is A Villa by the Sea.
# ------------
# Retrieving Results for Index 537: Tegul'det.
# Closest hotel in Tegul'det is Gostinitsa Kedr.
# ------------
# Retrieving Results for Index 538: Yamachiche.
# Closest hotel in Yamachiche is Hôtel Lyston Inn.
# ------------
# Retrieving Results for Index 539: Tuatapere.
# Closest hotel in Tuatapere is Last Light Lodge.
# ------------
# Retrieving Results for Index 540: Lødingen.
# Closest hotel in Lødingen is Brygga Hotell & Restaurant.
# ------------
# Retrieving Results for Index 541: Wajid.
# Closest hotel in Wajid is Hotel Haji Aden Yare.
# ------------
# Retrieving Results for Index 542: Caravelas.
# Closest hotel in Caravelas is Pousada Encanto Abrolhos.
# ------------
# Retrieving Results for Index 543: Alta Floresta.
# Closest hotel in Alta Floresta is Hotel Mandino.
# ------------
# Retrieving Results for Index 544: Tual.
# Closest hotel in Tual is Grand Vilia Hotel.
# ------------
# Retrieving Results for Index 545: Acaraú.
# Closest hotel in Acaraú is Hotel Riviera.
# ------------
# Retrieving Results for Index 546: Algiers.
# Closest hotel in Algiers is Ferdi Lilly Hôtel.
# ------------
# Retrieving Results for Index 547: Ormara.
# Closest hotel in Ormara is Alqadri hotel zero point ormara.
# ------------
# Retrieving Results for Index 548: Yumen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 549: Falmouth.
# Closest hotel in Falmouth is Excellence Oyster Bay.
# ------------
# Retrieving Results for Index 550: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 551: Varkala.
# Closest hotel in Varkala is Deshadan Cliff & Beach Resort.
# ------------
# Retrieving Results for Index 552: Seia.
# Closest hotel in Seia is Hotel Eurosol Seia Camelo.
# ------------
# Retrieving Results for Index 553: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 554: Mogadishu.
# Closest hotel in Mogadishu is Dolphin Hotel.
# ------------
# Retrieving Results for Index 555: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 556: Antsirabe.
# Closest hotel in Antsirabe is Arotel.
# ------------
# Retrieving Results for Index 557: Lupiro.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 558: Urla.
# Closest hotel in Urla is Maison Vourla Hotel.
# ------------
# Retrieving Results for Index 559: San Rafael.
# Closest hotel in San Rafael is Tower Inn Hotel & Suites Casino Spa Convention Center.
# ------------
# Retrieving Results for Index 560: Tezu.
# Closest hotel in Tezu is Oshin Hotel.
# ------------
# Retrieving Results for Index 561: Ostrovnoy.
# Closest hotel in Ostrovnoy is Sberbank Rossii.
# ------------
# Retrieving Results for Index 562: Waterloo.
# Closest hotel in Waterloo is Companero Hotel.
# ------------
# Retrieving Results for Index 563: Oyotún.
# Closest hotel in Oyotún is Iglesia Adventista del Séptimo Dia Oyotún.
# ------------
# Retrieving Results for Index 564: Nicoya.
# Closest hotel in Nicoya is Hotel Doña Marta.
# ------------
# Retrieving Results for Index 565: Darlawn.
# Closest hotel in Darlawn is Risk Hotel.
# ------------
# Retrieving Results for Index 566: Cairns.
# Closest hotel in Cairns is Shangri-La Hotel, The Marina, Cairns.
# ------------
# Retrieving Results for Index 567: Røros.
# Closest hotel in Røros is Røros Hotell.
# ------------
# Retrieving Results for Index 568: Saldanha.
# Closest hotel in Saldanha is Hoedjiesbaai Hotel.
# ------------
# Retrieving Results for Index 569: Port Augusta.
# Closest hotel in Port Augusta is Crossroads Ecomotel.
# ------------
# Retrieving Results for Index 570: Riyadh.
# Closest hotel in Riyadh is voco Riyadh.
# ------------
# Retrieving Results for Index 571: Glasgow.
# Closest hotel in Glasgow is Hampton Inn Elkton.
# ------------
# Retrieving Results for Index 572: Matamba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 573: Iqaluit.
# Closest hotel in Iqaluit is Frobisher Inn.
# ------------
# Retrieving Results for Index 574: Mayumba.
# Closest hotel in Mayumba is LIKWALE LODGE.
# ------------
# Retrieving Results for Index 575: Thinadhoo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 576: St. Marys.
# Closest hotel in St. Marys is Riverview Hotel.
# ------------
# Retrieving Results for Index 577: Dicabisagan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 578: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 579: Quesnel.
# Closest hotel in Quesnel is Billy Barker Casino Hotel.
# ------------
# Retrieving Results for Index 580: Moree.
# Closest hotel in Moree is Albert Motel.
# ------------
# Retrieving Results for Index 581: Makokou.
# Closest hotel in Makokou is Hôtel Bélinga.
# ------------
# Retrieving Results for Index 582: Biasca.
# Closest hotel in Biasca is albergo nazionale.
# ------------
# Retrieving Results for Index 583: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 584: Petushki.
# Closest hotel in Petushki is Богдарня by KEYDOM.
# ------------
# Retrieving Results for Index 585: Sawtell.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 586: Pyra.
# Closest hotel in Pyra is Solo.
# ------------
# Retrieving Results for Index 587: Puerto Baquerizo Moreno.
# Closest hotel in Puerto Baquerizo Moreno is Casa Blanca.
# ------------
# Retrieving Results for Index 588: Santa Maria.
# Closest hotel in Santa Maria is Hilton Cabo Verde Sal Resort.
# ------------
# Retrieving Results for Index 589: Naryan-Mar.
# Closest hotel in Naryan-Mar is Печора.
# ------------
# Retrieving Results for Index 590: Trinidad.
# Closest hotel in Trinidad is Hostal Amenidades.
# ------------
# Retrieving Results for Index 591: Sinjār.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 592: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 593: Magnolia.
# Closest hotel in Magnolia is Hampton Inn Magnolia.
# ------------
# Retrieving Results for Index 594: Chodavaram.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 595: Zhigansk.
# Closest hotel in Zhigansk is Gostinichnyy Kompleks Aylgy.
# ------------
# Retrieving Results for Index 596: Massakory.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 597: Koutiala.
# Closest hotel in Koutiala is Hotel Flasso 1.
# ------------
# Retrieving Results for Index 598: Cockburn Town.
# Closest hotel in Cockburn Town is Osprey Beach Hotel.
# ------------
# Retrieving Results for Index 599: Podosinovets.
# Closest hotel in Podosinovets is Sberbank Rossii.
# ------------
# Retrieving Results for Index 600: Talnakh.
# Closest hotel in Talnakh is Talnakh Hotel.
# ------------
# Retrieving Results for Index 601: Porosozero.
# Closest hotel in Porosozero is Sberbank Rossii.
# ------------
# Retrieving Results for Index 602: Santa Marinella.
# Closest hotel in Santa Marinella is Mercure Civitavecchia Sunbay Park Hotel.
# ------------
# Retrieving Results for Index 603: Moose Factory.
# Closest hotel in Moose Factory is Super 8 by Wyndham Moosonee.
# ------------
# Retrieving Results for Index 604: Cairo.
# Closest hotel in Cairo is Fairmont Nile City Hotel, Cairo.
# ------------
# Retrieving Results for Index 605: Kirksville.
# Closest hotel in Kirksville is Baymont by Wyndham Kirksville University Area.
# ------------
# Retrieving Results for Index 606: Samarai.
# Closest hotel in Samarai is Nuli Sapi.
# ------------
# Retrieving Results for Index 607: Barra do Garças.
# Closest hotel in Barra do Garças is Odara Araguaia.
# ------------
# Retrieving Results for Index 608: Honiara.
# Closest hotel in Honiara is Heritage Park Hotel.
# ------------
# Retrieving Results for Index 609: Gardez.
# Closest hotel in Gardez is Dubai Hotel - دبی هوټل.
# ------------
# Retrieving Results for Index 610: Qaryat Sulūq.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 611: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 612: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 613: nan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 614: Troitsko-Pechorsk.
# Closest hotel in Troitsko-Pechorsk is Pechora Gostinitsa.
# ------------
# Retrieving Results for Index 615: Jalu.
# Closest hotel in Jalu is Jalu Hotel.
# ------------
# Retrieving Results for Index 616: Malé.
# Closest hotel in Malé is Hard Rock Hotel Maldives.
# ------------
# Retrieving Results for Index 617: Vao.
# Closest hotel in Vao is OURE TERA beach resort.
# ------------
# Retrieving Results for Index 618: Boyolangu.
# Closest hotel in Boyolangu is Crown Victoria Hotel.
# ------------
# Retrieving Results for Index 619: Inuvik.
# Closest hotel in Inuvik is Arctic Chalet LTD.
# ------------
# Retrieving Results for Index 620: Bestöbe.
# Missing field/result... skipping.
# ------------
# -------End of Search-------

# %%
#Display Hotel Name in DataFrame
hotel_df
# Out:
#               city_name country  latitude  longitude  \
# 0              Necochea      AR    -38.55     -58.74
# 1                Albany      AU    -35.02     117.89
# 2                  Safi      MA     32.30      -9.24
# 3    São Félix do Xingu      BR     -6.64     -51.99
# 4                   NaN     NaN       NaN        NaN
# ..                  ...     ...       ...        ...
# 616                Malé      MV      4.17      73.51
# 617                 Vao      NC    -22.67     167.48
# 618           Boyolangu      ID     -8.12     111.89
# 619              Inuvik      CA     68.35    -133.72
# 620             Bestöbe      KZ     52.50      73.10
#
#                                 Hotel Name
# 0        Hotel Ñikén Spa & Business Center
# 1    Six Degrees Albany CBD Boutique Hotel
# 2             RIAD LE CHEVAL BLANC - HÔTEL
# 3                            Hotel Serrano
# 4
# ..                                     ...
# 616               Hard Rock Hotel Maldives
# 617                 OURE TERA beach resort
# 618                   Crown Victoria Hotel
# 619                      Arctic Chalet LTD
# 620
#
# [621 rows x 5 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap

info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{city_name}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""


# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["latitude", "longitude"]]

# %%
# Plot Markers on Top of Heatmap
# Add Marker layer on Top of Heatmap
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markers)
# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-11-46a4fdaaf746> in <module>
#       1 # Plot Markers on Top of Heatmap
#       2 # Add Marker layer on Top of Heatmap
# ----> 3 markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
#       4 fig.add_layer(markers)
#       5 # Display figure
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
# --> 555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\marker.py in <listcomp>(.0)
#     553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
# --> 555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\marker.py in __init__(self, location, **kwargs)
#     190         kwargs = _resolve_info_box_kwargs(**kwargs)
#     191         kwargs['location'] = location
# --> 192         super(Marker, self).__init__(**kwargs)
#     193
#     194
#
# ~\anaconda3\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#     100                 )
#     101             latitude, longitude = value
# --> 102             return super(Point, self).validate(obj, (latitude, longitude))
#     103
#     104
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2240             return value
#    2241
# -> 2242         value = self.validate_elements(obj, value)
#    2243
#    2244         return value
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2442         for t, v in zip(self._traits, value):
#    2443             try:
# -> 2444                 v = t._validate(obj, v)
#    2445             except TraitError:
#    2446                 self.element_error(obj, v, t)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      64
#      65     def validate(self, obj, value):
# ---> 66         _validate_latitude(value)
#      67         return value
#      68
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in _validate_latitude(latitude)
#     306         raise InvalidPointException(
#     307             '{} is not a valid latitude. '
# --> 308             'Latitudes must lie between -90 and 90.'.format(latitude)
#     309         )
#     310
#
# InvalidPointException: nan is not a valid latitude. Latitudes must lie between -90 and 90.
